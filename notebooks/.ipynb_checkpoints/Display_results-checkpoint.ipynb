# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir)
import utils.display_results as dr

# %%
# %ls
# Out:
#  El volumen de la unidad C es OS
#  El número de serie del volumen es: 66BD-F88D
#
#  Directorio de C:\Users\Gerard Marrugat\Documents\Master\Foundations Of Data Science\TFM\FoodAnalysis\food_analysis-dag_labels\results
#
# 27/08/2019  17:34    <DIR>          .
# 27/08/2019  17:34    <DIR>          ..
# 27/08/2019  17:34    <DIR>          .ipynb_checkpoints
# 29/07/2019  12:45    <DIR>          __pycache__
# 01/07/2019  13:09    <DIR>          batch_2
# 05/07/2019  13:31    <DIR>          batch_8
# 20/08/2019  14:34             3.184 display_results.pyc
# 17/07/2019  12:27    <DIR>          Multitask
# 17/07/2019  17:21    <DIR>          Ontologies_10-07-2019_Recipes5K
# 17/07/2019  18:09    <DIR>          Ontologies_15-07-2019_Recipes5K
# 13/08/2019  09:56    <DIR>          Ontology_probabilities_VIREO
# 20/08/2019  19:25    <DIR>          precision_dishes
# 21/08/2019  13:18    <DIR>          precision_ingredients
# 18/07/2019  14:44    <DIR>          prueba_vireo
# ...

# %% [markdown]
# ## VIREO-172

# %%
#RESULTS DIRECTORY
results_dir = 'Ontology_probabilities_VIREO/'

# %% [markdown]
# ### Food Multitask without Ontology

# %%
mtl_results_multiclass = results_dir + 'food_multitask/2ª prueba/train.multiclass_metrics'
mtl_results_multilabel = results_dir + 'food_multitask/2ª prueba/train.multilabel_metrics'

# %%
multilabel_file = open(mtl_results_multilabel)
multilabel_results = multilabel_file.readlines()

# %%
epoch_mtl_mc, accuracy_mtl_mc, balanced_accuracy_mtl_mc, loss_mc, f1_mtl_mc, precision_mtl_mc, recall_mtl_mc, \
epoch_mtl_ml, average_precision_mtl_ml, loss_ml, coverage_error_mtl_ml, f1_mtl_ml, precision_mtl_ml, \
ranking_loss_mtl_ml, recall_mtl_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
mtl_val_results_multiclass = results_dir + 'food_multitask/2ª prueba/val.multiclass_metrics'
mtl_val_results_multilabel = results_dir + 'food_multitask/2ª prueba/val.multilabel_metrics'

# %%
multilabel_file = open(mtl_results_multilabel)
multilabel_results = multilabel_file.readlines()

# %%
epoch_mtl_val_mc, accuracy_mtl_val_mc, balanced_accuracy_mtl_val_mc, loss_val_mc, f1_mtl_val_mc, precision_mtl_val_mc, recall_mtl_val_mc, \
epoch_mtl_val_ml, average_precision_mtl_val_ml, loss_val_ml, coverage_error_mtl_val_ml, f1_mtl_val_ml, precision_mtl_val_ml, \
ranking_loss_mtl_val_ml, recall_mtl_val_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_mc, accuracy_mtl_val_mc, epoch_mtl_val_ml, f1_mtl_val_ml, precision_mtl_val_ml, recall_mtl_val_ml, 'Multitask Baseline')

# %%
mtl_test_results_multiclass = results_dir + 'food_multitask/2ª prueba/test.multiclass_metrics'
mtl_test_results_multilabel = results_dir + 'food_multitask/2ª prueba/test.multilabel_metrics'

# %%
epoch_mtl_test_mc, accuracy_mtl_test_mc, balanced_accuracy_mtl_test_mc, loss_test_mc, f1_mtl_test_mc, precision_mtl_test_mc, recall_mtl_test_mc, \
epoch_mtl_test_ml, average_precision_mtl_test_ml, loss_test_ml, coverage_error_mtl_test_ml, f1_mtl_test_ml, precision_mtl_test_ml, \
ranking_loss_mtl_test_ml, recall_mtl_test_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_mc,
            'accuracy_mtl_val':accuracy_mtl_mc,'accuracy_mtl_test':accuracy_mtl_test_mc,
            'f1-score_mtl_val':f1_mtl_ml,'f1-score_mtl_test':f1_mtl_test_ml,
            'precision_mtl_val':precision_mtl_ml, 'precision_mtl_test':precision_mtl_test_ml,
            'recall_mtl_val':recall_mtl_ml, 'recall_mtl_test':recall_mtl_test_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.778141           0.774296          0.526827
# 1       2          0.809005           0.810370          0.607474
# 2       3          0.827524           0.821289          0.636818
# 3       4          0.835149           0.830337          0.660550
# 4       5          0.832970           0.835676          0.646699
# 5       6          0.834877           0.832931          0.654528
# 6       7          0.846405           0.844845          0.675311
# 7       8          0.841685           0.838903          0.667252
# 8       9          0.845225           0.840351          0.677664
# 9      10          0.853123           0.846565          0.677662
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.526580           0.796480            0.793336        0.393578
# 1           0.603923           0.774559            0.772558        0.499684
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 8       9          0.845225           0.840351          0.677664
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 8           0.675074           0.777038            0.773776        0.600825
#
#    recall_mtl_test
# 8         0.598704

# %%
loss = np.array(loss_mc)+np.array(loss_ml)
loss_val = np.array(loss_val_mc)+np.array(loss_val_ml)
loss_test = np.array(loss_test_mc)+np.array(loss_test_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_mc, loss, label='train_loss')
ax.plot(epoch_mtl_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# ### Ontology_1 (elements of the matrix are 1´s and 0´s)

# %%
ont_dir = results_dir + 'Ontology_1/'

# %% [markdown]
# #### Dish-Ingredient (the ontology contains the top-down relation between dishes and ingredients)

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/val.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
dr.plot_metrics(epoch_mtl_di_mc, accuracy_mtl_di_mc, epoch_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, recall_mtl_di_ml, 'Dish-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, balanced_accuracy_mtl_test_di_mc, f1_mtl_test_di_mc, precision_mtl_test_di_mc, recall_mtl_test_di_mc, \
epoch_mtl_test_di_ml, average_precision_mtl_test_di_ml, coverage_error_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, \
ranking_loss_mtl_test_di_ml, recall_mtl_test_di_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_di_mc,
            'accuracy_mtl_val':accuracy_mtl_di_mc,'accuracy_mtl_test':accuracy_mtl_test_di_mc,
            'f1-score_mtl_val':f1_mtl_di_ml,'f1-score_mtl_test':f1_mtl_test_di_ml,
            'precision_mtl_val':precision_mtl_di_ml, 'precision_mtl_test':precision_mtl_test_di_ml,
            'recall_mtl_val':recall_mtl_di_ml, 'recall_mtl_test':recall_mtl_test_di_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.764252           0.762412          0.407982
# 1       2          0.810276           0.804006          0.452808
# 2       3          0.807280           0.804729          0.471509
# 3       4          0.829975           0.829855          0.491200
# 4       5          0.831972           0.830156          0.497573
# 5       6          0.832970           0.831936          0.495465
# 6       7          0.845588           0.848495          0.512853
# 7       8          0.837781           0.836128          0.503474
# 8       9          0.843682           0.839899          0.510887
# 9      10          0.837509           0.838903          0.506524
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.408577           0.575698            0.576724        0.315940
# 1           0.452712           0.664589            0.658860        0.343384
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 6       7          0.845588           0.848495          0.512853
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 6           0.512684           0.738074            0.734725        0.392946
#
#    recall_mtl_test
# 6         0.393703

# %% [markdown]
# #### Ingredient-Dish (the ontology contains the bottom-up relation between dishes and ingredients)

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_dish_ont/val.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_dish_ont/val.multilabel_metrics'

# %%
epoch_mtl_id_mc, accuracy_mtl_id_mc, balanced_accuracy_mtl_id_mc, f1_mtl_id_mc, precision_mtl_id_mc, recall_mtl_id_mc, \
epoch_mtl_id_ml, average_precision_mtl_id_ml, coverage_error_mtl_id_ml, f1_mtl_id_ml, precision_mtl_id_ml, \
ranking_loss_mtl_id_ml, recall_mtl_id_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
dr.plot_metrics(epoch_mtl_id_mc, accuracy_mtl_id_mc, epoch_mtl_id_ml, f1_mtl_id_ml, precision_mtl_id_ml, recall_mtl_id_ml, 'Ingredient-Dish')

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_dish_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_id_mc, accuracy_mtl_test_id_mc, balanced_accuracy_mtl_test_id_mc, f1_mtl_test_id_mc, precision_mtl_test_id_mc, recall_mtl_test_id_mc, \
epoch_mtl_test_id_ml, average_precision_mtl_test_id_ml, coverage_error_mtl_test_id_ml, f1_mtl_test_id_ml, precision_mtl_test_id_ml, \
ranking_loss_mtl_test_id_ml, recall_mtl_test_id_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_id_mc,
            'accuracy_mtl_val':accuracy_mtl_id_mc,'accuracy_mtl_test':accuracy_mtl_test_id_mc,
            'f1-score_mtl_val':f1_mtl_id_ml,'f1-score_mtl_test':f1_mtl_test_id_ml,
            'precision_mtl_val':precision_mtl_id_ml, 'precision_mtl_test':precision_mtl_test_id_ml,
            'recall_mtl_val':recall_mtl_id_ml, 'recall_mtl_test':recall_mtl_test_id_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.744281           0.745883          0.064752
# 1       2          0.789216           0.785245          0.075004
# 2       3          0.801380           0.796103          0.086706
# 3       4          0.804466           0.803523          0.095688
# 4       5          0.837328           0.832117          0.108229
# 5       6          0.796387           0.793871          0.117275
# 6       7          0.804375           0.803493          0.127599
# 7       8          0.821351           0.818333          0.134136
# 8       9          0.824982           0.818182          0.157146
# 9      10          0.816903           0.817096          0.152650
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.064548           0.034520            0.034407        0.521351
# 1           0.074610           0.040860            0.040633        0.456351
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 8       9          0.824982           0.818182          0.157146
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 8           0.155776           0.111399            0.110337        0.266649
#
#    recall_mtl_test
# 8         0.264846

# %% [markdown]
# #### Dish-Ingredient Ingredient-Dish (the ontology contains the top-down and bottom-up relation between dishes and ingredients)

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/val.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/val.multilabel_metrics'

# %%
epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, balanced_accuracy_mtl_di_id_mc, f1_mtl_di_id_mc, precision_mtl_di_id_mc, recall_mtl_di_id_mc, \
epoch_mtl_di_id_ml, average_precision_mtl_di_id_ml, coverage_error_mtl_di_id_ml, f1_mtl_di_id_ml, precision_mtl_di_id_ml, \
ranking_loss_mtl_di_id_ml, recall_mtl_di_id_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
dr.plot_metrics(epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, epoch_mtl_di_id_ml, f1_mtl_di_id_ml, precision_mtl_di_id_ml, recall_mtl_di_id_ml, 'Dish-Ingredient Ingredient-Dish')

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_id_mc, accuracy_mtl_test_di_id_mc, balanced_accuracy_mtl_test_di_id_mc, f1_mtl_test_di_id_mc, precision_mtl_test_di_id_mc, recall_mtl_test_di_id_mc, \
epoch_mtl_test_di_id_ml, average_precision_mtl_test_di_id_ml, coverage_error_mtl_test_di_id_ml, f1_mtl_test_di_id_ml, precision_mtl_test_di_id_ml, \
ranking_loss_mtl_test_di_id_ml, recall_mtl_test_di_id_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_di_id_mc,
            'accuracy_mtl_val':accuracy_mtl_di_id_mc,'accuracy_mtl_test':accuracy_mtl_test_di_id_mc,
            'f1-score_mtl_val':f1_mtl_di_id_ml,'f1-score_mtl_test':f1_mtl_test_di_id_ml,
            'precision_mtl_val':precision_mtl_di_id_ml, 'precision_mtl_test':precision_mtl_test_di_id_ml,
            'recall_mtl_val':recall_mtl_di_id_ml, 'recall_mtl_test':recall_mtl_test_di_id_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.061093           0.059751          0.019601
# 1       2          0.798656           0.796827          0.152989
# 2       3          0.793210           0.791126          0.177153
# 3       4          0.811002           0.808017          0.206279
# 4       5          0.804920           0.804428          0.232291
# 5       6          0.818718           0.810219          0.258605
# 6       7          0.818627           0.823068          0.298352
# 7       8          0.815269           0.809706          0.285937
# 8       9          0.818355           0.813145          0.332067
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.019455           0.515528            0.499243        0.009991
# 1           0.154793           0.624219            0.616287        0.087178
# 2           0.176944           0.659682            0.660527        0.102314
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 8       9          0.818355           0.813145          0.332067
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 8           0.334689            0.64577            0.640606        0.223496
#
#    recall_mtl_test
# 8         0.226518

# %% [markdown]
# #### Ingredient-Ingredient (the ontology contains the coexistence relation between ingredients)

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/val.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
dr.plot_metrics(epoch_mtl_ii_mc, accuracy_mtl_ii_mc, epoch_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, recall_mtl_ii_ml, 'Ingredient-Ingredient')

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_ii_mc, accuracy_mtl_test_ii_mc, balanced_accuracy_mtl_test_ii_mc, f1_mtl_test_ii_mc, precision_mtl_test_ii_mc, recall_mtl_test_ii_mc, \
epoch_mtl_test_ii_ml, average_precision_mtl_test_ii_ml, coverage_error_mtl_test_ii_ml, f1_mtl_test_ii_ml, precision_mtl_test_ii_ml, \
ranking_loss_mtl_test_ii_ml, recall_mtl_test_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_ii_mc,
            'f1-score_mtl_val':f1_mtl_ii_ml,'f1-score_mtl_test':f1_mtl_test_ii_ml,
            'precision_mtl_val':precision_mtl_ii_ml, 'precision_mtl_test':precision_mtl_test_ii_ml,
            'recall_mtl_val':recall_mtl_ii_ml, 'recall_mtl_test':recall_mtl_test_ii_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.773420           0.771641          0.437280
# 1       2          0.791304           0.790433          0.564024
# 2       3          0.813272           0.809887          0.618353
# 3       4          0.816903           0.818785          0.591961
# 4       5          0.823348           0.826145          0.643280
# 5       6          0.837691           0.835917          0.662308
# 6       7          0.833061           0.831544          0.607149
# 7       8          0.843137           0.842131          0.622741
# 8       9          0.836601           0.835254          0.659738
# 9      10          0.846405           0.840653          0.679187
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.435174           0.801943            0.804023        0.300593
# 1           0.560024           0.781002            0.778671        0.441395
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.846405           0.840653          0.679187
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.673992           0.738048            0.732371        0.629021
#
#    recall_mtl_test
# 9         0.624233

# %% [markdown]
# #### Full

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_full_ont/val.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_full_ont/val.multilabel_metrics'

# %%
epoch_mtl_full_mc, accuracy_mtl_full_mc, balanced_accuracy_mtl_full_mc, f1_mtl_full_mc, precision_mtl_full_mc, recall_mtl_full_mc, \
epoch_mtl_full_ml, average_precision_mtl_full_ml, coverage_error_mtl_full_ml, f1_mtl_full_ml, precision_mtl_full_ml, \
ranking_loss_mtl_full_ml, recall_mtl_full_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
dr.plot_metrics(epoch_mtl_full_mc, accuracy_mtl_full_mc, epoch_mtl_full_ml, f1_mtl_full_ml, precision_mtl_full_ml, recall_mtl_full_ml, 'Full')

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_full_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_full_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_full_mc, accuracy_mtl_test_full_mc, balanced_accuracy_mtl_test_full_mc, f1_mtl_test_full_mc, precision_mtl_test_full_mc, recall_mtl_test_full_mc, \
epoch_mtl_test_full_ml, average_precision_mtl_test_full_ml, coverage_error_mtl_test_full_ml, f1_mtl_test_full_ml, precision_mtl_test_full_ml, \
ranking_loss_mtl_test_full_ml, recall_mtl_test_full_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_full_mc,
            'accuracy_mtl_val':accuracy_mtl_full_mc,'accuracy_mtl_test':accuracy_mtl_test_full_mc,
            'f1-score_mtl_val':f1_mtl_full_ml,'f1-score_mtl_test':f1_mtl_test_full_ml,
            'precision_mtl_val':precision_mtl_full_ml, 'precision_mtl_test':precision_mtl_test_full_ml,
            'recall_mtl_val':recall_mtl_full_ml, 'recall_mtl_test':recall_mtl_test_full_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.751362           0.743289          0.276329
# 1       2          0.783406           0.780569          0.347385
# 2       3          0.819354           0.818272          0.397746
# 3       4          0.804375           0.804729          0.470637
# 4       5          0.795025           0.796435          0.483051
# 5       6          0.818355           0.819931          0.514803
# 6       7          0.826071           0.823822          0.525934
# 7       8          0.817810           0.810611          0.519325
# 8       9          0.832879           0.831936          0.539798
# 9      10          0.816449           0.810249          0.539704
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.277905           0.370391            0.368222        0.220367
# 1           0.348994           0.406951            0.407122        0.303030
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 8       9          0.832879           0.831936          0.539798
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 8           0.536043           0.594264            0.587252        0.494478
#
#    recall_mtl_test
# 8         0.493049

# %% [markdown]
# ### Ontology_prob (elements of the matrix are probabilities)

# %%
ont_dir = results_dir + 'Ontology_prob/'

# %% [markdown]
# #### Dish-Ingredient (the ontology contains the top-down relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, balanced_accuracy_mtl_val_di_mc, loss_val_di_mc, f1_mtl_val_di_mc, precision_mtl_val_di_mc, recall_mtl_val_di_mc, \
epoch_mtl_val_di_ml, average_precision_mtl_val_di_ml, loss_val_di_ml, coverage_error_mtl_val_di_ml, f1_mtl_val_di_ml, precision_mtl_val_di_ml, \
ranking_loss_mtl_val_di_ml, recall_mtl_val_di_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, epoch_mtl_val_di_ml, f1_mtl_val_di_ml, precision_mtl_val_di_ml, recall_mtl_val_di_ml, 'Dish-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, balanced_accuracy_mtl_test_di_mc, loss_test_di_mc, f1_mtl_test_di_mc, precision_mtl_test_di_mc, recall_mtl_test_di_mc, \
epoch_mtl_test_di_ml, average_precision_mtl_test_di_ml, loss_test_di_ml, coverage_error_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, \
ranking_loss_mtl_test_di_ml, recall_mtl_test_di_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_mc,'accuracy_mtl_test':accuracy_mtl_test_di_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ml,'f1-score_mtl_test':f1_mtl_test_di_ml,
            'precision_mtl_val':precision_mtl_val_di_ml, 'precision_mtl_test':precision_mtl_test_di_ml,
            'recall_mtl_val':recall_mtl_val_di_ml, 'recall_mtl_test':recall_mtl_test_di_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.768700           0.766423          0.601469
# 1       2          0.799110           0.798003          0.635664
# 2       3          0.820261           0.823671          0.641032
# 3       4          0.832335           0.834862          0.644810
# 4       5          0.823076           0.821892          0.658280
# 5       6          0.838780           0.835646          0.661092
# 6       7          0.844136           0.841196          0.671705
# 7       8          0.841594           0.837214          0.665568
# 8       9          0.853758           0.854527          0.678983
# 9      10          0.838780           0.836159          0.663715
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.598564           0.653557            0.651263        0.557070
# 1           0.632163           0.688061            0.686614        0.590683
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 8       9          0.853758           0.854527          0.678983
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 8           0.676583           0.763056            0.759422        0.611598
#
#    recall_mtl_test
# 8         0.610039

# %%
dr.plot_metrics(epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, epoch_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, recall_mtl_test_di_ml, 'Dish-Ingredient')

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, loss_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, loss_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_di_mc)+np.array(loss_val_di_ml)
loss_test = np.array(loss_test_di_mc)+np.array(loss_test_di_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Dish-Ingredient (20 epochs)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont_20_epochs/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont_20_epochs/val.multilabel_metrics'

# %%
epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, balanced_accuracy_mtl_val_di_mc, loss_val_di_mc, f1_mtl_val_di_mc, precision_mtl_val_di_mc, recall_mtl_val_di_mc, \
epoch_mtl_val_di_ml, average_precision_mtl_val_di_ml, loss_val_di_ml, coverage_error_mtl_val_di_ml, f1_mtl_val_di_ml, precision_mtl_val_di_ml, \
ranking_loss_mtl_val_di_ml, recall_mtl_val_di_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont_20_epochs/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont_20_epochs/test.multilabel_metrics'

# %%
epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, balanced_accuracy_mtl_test_di_mc, loss_test_di_mc, f1_mtl_test_di_mc, precision_mtl_test_di_mc, recall_mtl_test_di_mc, \
epoch_mtl_test_di_ml, average_precision_mtl_test_di_ml, loss_test_di_ml, coverage_error_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, \
ranking_loss_mtl_test_di_ml, recall_mtl_test_di_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, accuracy_mtl_test_di_mc, epoch_mtl_val_di_ml, 
                f1_mtl_val_di_ml, f1_mtl_test_di_ml, precision_mtl_val_di_ml, precision_mtl_test_di_ml, recall_mtl_val_di_ml, 
                recall_mtl_test_di_ml, 'Dish-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_mc,'accuracy_mtl_test':accuracy_mtl_test_di_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ml,'f1-score_mtl_test':f1_mtl_test_di_ml,
            'precision_mtl_val':precision_mtl_val_di_ml, 'precision_mtl_test':precision_mtl_test_di_ml,
            'recall_mtl_val':recall_mtl_val_di_ml, 'recall_mtl_test':recall_mtl_test_di_ml})

# %%
models_results_df
# Out:
#     epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0        1          0.769789           0.769440          0.601405
# 1        2          0.798203           0.796555          0.622123
# 2        3          0.826071           0.821831          0.646354
# 3        4          0.821714           0.823521          0.647183
# 4        5          0.833152           0.830277          0.650832
# 5        6          0.838598           0.837425          0.663495
# 6        7          0.836692           0.837094          0.665681
# 7        8          0.832607           0.834258          0.669385
# 8        9          0.831518           0.830036          0.661926
# 9       10          0.841231           0.839537          0.671704
# 10      11          0.820261           0.814562          0.655597
# 11      12          0.839415           0.837184          0.672674
# 12      13          0.843046           0.837848          0.675920
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#     epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 14      15          0.838508           0.842161          0.685378
#
#     f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 14           0.683087           0.770967            0.766282        0.616894
#
#     recall_mtl_test
# 14         0.616188

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont_20_epochs/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont_20_epochs/train.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, loss_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, loss_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_di_mc)+np.array(loss_val_di_ml)
loss_test = np.array(loss_test_di_mc)+np.array(loss_test_di_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Ingredient-Dish (the ontology contains the bottom-up relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_ingr_dish_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_ingr_dish_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_id_mc, accuracy_mtl_val_id_mc, balanced_accuracy_mtl_val_id_mc, loss_val_id_mc, f1_mtl_val_id_mc, precision_mtl_val_id_mc, recall_mtl_val_id_mc, \
epoch_mtl_val_id_ml, average_precision_mtl_val_id_ml, loss_val_id_ml, coverage_error_mtl_val_id_ml, f1_mtl_val_id_ml, precision_mtl_val_id_ml, \
ranking_loss_mtl_val_id_ml, recall_mtl_val_id_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_id_mc, accuracy_mtl_val_id_mc, epoch_mtl_val_id_ml, f1_mtl_val_id_ml, precision_mtl_val_id_ml, recall_mtl_val_id_ml, 'Ingredient-Dish')

# %% [markdown]
# #### Evaluation over test set

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_dish_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_id_mc, accuracy_mtl_test_id_mc, balanced_accuracy_mtl_test_id_mc, loss_test_id_mc, f1_mtl_test_id_mc, precision_mtl_test_id_mc, recall_mtl_test_id_mc, \
epoch_mtl_test_id_ml, average_precision_mtl_test_id_ml, loss_test_id_ml, coverage_error_mtl_test_id_ml, f1_mtl_test_id_ml, precision_mtl_test_id_ml, \
ranking_loss_mtl_test_id_ml, recall_mtl_test_id_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_id_mc,
            'accuracy_mtl_val':accuracy_mtl_val_id_mc,'accuracy_mtl_test':accuracy_mtl_test_id_mc,
            'f1-score_mtl_val':f1_mtl_val_id_ml,'f1-score_mtl_test':f1_mtl_test_id_ml,
            'precision_mtl_val':precision_mtl_val_id_ml, 'precision_mtl_test':precision_mtl_test_id_ml,
            'recall_mtl_val':recall_mtl_val_id_ml, 'recall_mtl_test':recall_mtl_test_id_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.739288           0.741328          0.392819
# 1       2          0.784858           0.781625          0.432269
# 2       3          0.812364           0.803191          0.477074
# 3       4          0.832789           0.827804          0.501750
# 4       5          0.796478           0.803644          0.474174
# 5       6          0.819172           0.824667          0.543801
# 6       7          0.842774           0.840834          0.546984
# 7       8          0.833878           0.830940          0.537718
# 8       9          0.831699           0.830186          0.567285
# 9      10          0.835330           0.834590          0.575177
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.394981           0.499675            0.504380        0.323613
# 1           0.430121           0.677370            0.675814        0.317414
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10           0.83533            0.83459          0.575177
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.571411           0.771799            0.772012        0.458397
#
#    recall_mtl_test
# 9         0.453557

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_dish_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_dish_ont/train.multilabel_metrics'

# %%
epoch_mtl_id_mc, accuracy_mtl_id_mc, balanced_accuracy_mtl_id_mc, loss_id_mc, f1_mtl_id_mc, precision_mtl_id_mc, recall_mtl_id_mc, \
epoch_mtl_id_ml, average_precision_mtl_id_ml, loss_id_ml, coverage_error_mtl_id_ml, f1_mtl_id_ml, precision_mtl_id_ml, \
ranking_loss_mtl_id_ml, recall_mtl_id_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_id_mc)+np.array(loss_id_ml)
loss_val = np.array(loss_val_id_mc)+np.array(loss_val_id_ml)
loss_test = np.array(loss_test_id_mc)+np.array(loss_test_id_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_id_mc, loss, label='train_loss')
ax.plot(epoch_mtl_id_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Dish-Ingredient Ingredient-Ingredient (the ontology contains the bottom-up relation between dishes and ingredients, and pair coexistence relation ingredient)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_ii_mc, accuracy_mtl_val_di_ii_mc, balanced_accuracy_mtl_val_di_ii_mc, loss_val_di_ii_mc, f1_mtl_val_di_ii_mc, precision_mtl_val_di_ii_mc, recall_mtl_val_di_ii_mc, \
epoch_mtl_val_di_ii_ml, average_precision_mtl_val_di_ii_ml, loss_val_di_ii_ml, coverage_error_mtl_val_di_ii_ml, f1_mtl_val_di_ii_ml, precision_mtl_val_di_ii_ml, \
ranking_loss_mtl_val_di_ii_ml, recall_mtl_val_di_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_ii_mc, accuracy_mtl_test_di_ii_mc, balanced_accuracy_mtl_test_di_ii_mc, loss_test_di_ii_mc, f1_mtl_test_di_ii_mc, precision_mtl_test_di_ii_mc, recall_mtl_test_di_ii_mc, \
epoch_mtl_test_di_ii_ml, average_precision_mtl_test_di_ii_ml, loss_test_di_ii_ml, coverage_error_mtl_test_di_ii_ml, f1_mtl_test_di_ii_ml, precision_mtl_test_di_ii_ml, \
ranking_loss_mtl_test_di_ii_ml, recall_mtl_test_di_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_ii_mc, accuracy_mtl_val_di_ii_mc, accuracy_mtl_test_di_ii_mc, epoch_mtl_val_di_ii_ml, f1_mtl_val_id_ml, f1_mtl_test_di_ii_ml,
                precision_mtl_val_di_ii_ml, precision_mtl_test_di_ii_ml, recall_mtl_val_di_ii_ml, recall_mtl_test_di_ii_ml, 'Dish-Ingredient Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_di_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ii_ml,'f1-score_mtl_test':f1_mtl_test_di_ii_ml,
            'precision_mtl_val':precision_mtl_val_di_ii_ml, 'precision_mtl_test':precision_mtl_test_di_ii_ml,
            'recall_mtl_val':recall_mtl_val_di_ii_ml, 'recall_mtl_test':recall_mtl_test_di_ii_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.762890           0.761115          0.514843
# 1       2          0.810094           0.812059          0.564402
# 2       3          0.817084           0.817277          0.571722
# 3       4          0.833969           0.835284          0.581952
# 4       5          0.822440           0.821500          0.579523
# 5       6          0.828794           0.827291          0.593618
# 6       7          0.827796           0.830820          0.589753
# 7       8          0.812818           0.815166          0.574128
# 8       9          0.823166           0.818544          0.589152
# 9      10          0.830519           0.830971          0.597028
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.514452           0.654505            0.649093        0.424303
# 1           0.562090           0.739099            0.731183        0.456501
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.830519           0.830971          0.597028
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9            0.59833           0.736886            0.737082         0.50179
#
#    recall_mtl_test
# 9         0.503541

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_ii_mc, accuracy_mtl_di_ii_mc, balanced_accuracy_mtl_di_ii_mc, loss_di_ii_mc, f1_mtl_di_ii_mc, precision_mtl_di_ii_mc, recall_mtl_di_ii_mc, \
epoch_mtl_di_ii_ml, average_precision_mtl_di_ii_ml, loss_di_ii_ml, coverage_error_mtl_di_ii_ml, f1_mtl_di_ii_ml, precision_mtl_di_ii_ml, \
ranking_loss_mtl_di_ii_ml, recall_mtl_di_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_ii_mc)+np.array(loss_di_ii_ml)
loss_val = np.array(loss_val_di_ii_mc)+np.array(loss_val_di_ii_ml)
loss_test = np.array(loss_test_di_ii_mc)+np.array(loss_test_di_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_ii_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Dish-Ingredient_Ingredient-Dish (the ontology contains the top-down and bottom-up relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_id_mc, accuracy_mtl_val_di_id_mc, balanced_accuracy_mtl_val_di_id_mc, loss_val_di_id_mc, f1_mtl_val_di_id_mc, precision_mtl_val_di_id_mc, recall_mtl_val_di_id_mc, \
epoch_mtl_val_di_id_ml, average_precision_mtl_val_di_id_ml, loss_val_di_id_ml, coverage_error_mtl_val_di_id_ml, f1_mtl_val_di_id_ml, precision_mtl_val_di_id_ml, \
ranking_loss_mtl_val_di_id_ml, recall_mtl_val_di_id_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_id_mc, accuracy_mtl_val_di_id_mc, epoch_mtl_val_di_id_ml, f1_mtl_val_di_id_ml, precision_mtl_val_di_id_ml, recall_mtl_val_di_id_ml, 'Dish-Ingredient Ingredient-Dish')

# %% [markdown]
# #### Evaluation over test set

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_id_mc, accuracy_mtl_test_di_id_mc, balanced_accuracy_mtl_test_di_id_mc, loss_test_di_id_mc, f1_mtl_test_di_id_mc, precision_mtl_test_di_id_mc, recall_mtl_test_di_id_mc, \
epoch_mtl_test_di_id_ml, average_precision_mtl_test_di_id_ml, loss_test_di_id_ml, coverage_error_mtl_test_di_id_ml, f1_mtl_test_di_id_ml, precision_mtl_test_di_id_ml, \
ranking_loss_mtl_test_di_id_ml, recall_mtl_test_di_id_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_id_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_id_mc,'accuracy_mtl_test':accuracy_mtl_test_di_id_mc,
            'f1-score_mtl_val':f1_mtl_val_di_id_ml,'f1-score_mtl_test':f1_mtl_test_di_id_ml,
            'precision_mtl_val':precision_mtl_val_di_id_ml, 'precision_mtl_test':precision_mtl_test_di_id_ml,
            'recall_mtl_val':recall_mtl_val_di_id_ml, 'recall_mtl_test':recall_mtl_test_di_id_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.776961           0.781324          0.360147
# 1       2          0.794935           0.790583          0.395202
# 2       3          0.787309           0.781052          0.428953
# 3       4          0.814452           0.812511          0.469229
# 4       5          0.810276           0.810038          0.478483
# 5       6          0.818991           0.818845          0.489912
# 6       7          0.814270           0.815709          0.500333
# 7       8          0.833969           0.837275          0.518710
# 8       9          0.820080           0.812481          0.514429
# 9      10          0.831064           0.831996          0.520705
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.364310           0.367902            0.373429        0.352713
# 1           0.395866           0.401986            0.403001        0.388643
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.831064           0.831996          0.520705
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.521088           0.604866            0.606511        0.457103
#
#    recall_mtl_test
# 9         0.456757

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, balanced_accuracy_mtl_di_id_mc, loss_di_id_mc, f1_mtl_di_id_mc, precision_mtl_di_id_mc, recall_mtl_di_id_mc, \
epoch_mtl_di_id_ml, average_precision_mtl_di_id_ml, loss_di_id_ml, coverage_error_mtl_di_id_ml, f1_mtl_di_id_ml, precision_mtl_di_id_ml, \
ranking_loss_mtl_di_id_ml, recall_mtl_di_id_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_id_mc)+np.array(loss_di_id_ml)
loss_val = np.array(loss_val_di_id_mc)+np.array(loss_val_di_id_ml)
loss_test = np.array(loss_test_di_id_mc)+np.array(loss_test_di_id_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_id_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_id_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Ingredient-Ingredient (the ontology contains the coexistence relation between ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, balanced_accuracy_mtl_val_ii_mc, loss_val_ii_mc, f1_mtl_val_ii_mc, precision_mtl_val_ii_mc, recall_mtl_val_ii_mc, \
epoch_mtl_val_ii_ml, average_precision_mtl_val_ii_ml, loss_val_ii_ml, coverage_error_mtl_val_ii_ml, f1_mtl_val_ii_ml, precision_mtl_val_ii_ml, \
ranking_loss_mtl_val_ii_ml, recall_mtl_val_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, epoch_mtl_val_ii_ml, f1_mtl_val_ii_ml, precision_mtl_val_ii_ml, recall_mtl_val_ii_ml, 'Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_ii_mc, accuracy_mtl_test_ii_mc, balanced_accuracy_mtl_test_ii_mc, loss_test_ii_mc, f1_mtl_test_ii_mc, precision_mtl_test_ii_mc, recall_mtl_test_ii_mc, \
epoch_mtl_test_ii_ml, average_precision_mtl_test_ii_ml, loss_test_ii_ml, coverage_error_mtl_test_ii_ml, f1_mtl_test_ii_ml, precision_mtl_test_ii_ml, \
ranking_loss_mtl_test_ii_ml, recall_mtl_test_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_ii_ml,'f1-score_mtl_test':f1_mtl_test_ii_ml,
            'precision_mtl_val':precision_mtl_val_ii_ml, 'precision_mtl_test':precision_mtl_test_ii_ml,
            'recall_mtl_val':recall_mtl_val_ii_ml, 'recall_mtl_test':recall_mtl_test_ii_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.750635           0.752971          0.466572
# 1       2          0.806463           0.807052          0.527003
# 2       3          0.823257           0.822947          0.552414
# 3       4          0.827796           0.827231          0.552924
# 4       5          0.838871           0.835163          0.580812
# 5       6          0.837146           0.836762          0.579764
# 6       7          0.844590           0.844725          0.588641
# 7       8          0.831881           0.828045          0.583775
# 8       9          0.843410           0.845087          0.586296
# 9      10          0.852760           0.846022          0.589176
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.467858           0.740770            0.737793        0.340525
# 1           0.527052           0.786991            0.787394        0.396136
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10           0.85276           0.846022          0.589176
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.586604           0.808686            0.802539        0.463393
#
#    recall_mtl_test
# 9         0.462234

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, loss_ii_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, loss_ii_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_ii_mc)+np.array(loss_ii_ml)
loss_val = np.array(loss_val_ii_mc)+np.array(loss_val_ii_ml)
loss_test = np.array(loss_test_ii_mc)+np.array(loss_test_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_ii_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Ingredient-Ingredient (20 epochs)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont_20_epochs/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont_20_epochs/val.multilabel_metrics'

# %%
epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, balanced_accuracy_mtl_val_ii_mc, loss_val_ii_mc, f1_mtl_val_ii_mc, precision_mtl_val_ii_mc, recall_mtl_val_ii_mc, \
epoch_mtl_val_ii_ml, average_precision_mtl_val_ii_ml, loss_val_ii_ml, coverage_error_mtl_val_ii_ml, f1_mtl_val_ii_ml, precision_mtl_val_ii_ml, \
ranking_loss_mtl_val_ii_ml, recall_mtl_val_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont_20_epochs/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont_20_epochs/test.multilabel_metrics'

# %%
epoch_mtl_test_ii_mc, accuracy_mtl_test_ii_mc, balanced_accuracy_mtl_test_ii_mc, loss_test_ii_mc, f1_mtl_test_ii_mc, precision_mtl_test_ii_mc, recall_mtl_test_ii_mc, \
epoch_mtl_test_ii_ml, average_precision_mtl_test_ii_ml, loss_test_ii_ml, coverage_error_mtl_test_ii_ml, f1_mtl_test_ii_ml, precision_mtl_test_ii_ml, \
ranking_loss_mtl_test_ii_ml, recall_mtl_test_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, accuracy_mtl_test_ii_mc, epoch_mtl_val_ii_ml, 
                f1_mtl_val_ii_ml, f1_mtl_test_ii_ml, precision_mtl_val_ii_ml, precision_mtl_test_ii_ml,
                recall_mtl_val_ii_ml, recall_mtl_test_ii_ml,'Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_ii_ml,'f1-score_mtl_test':f1_mtl_test_ii_ml,
            'precision_mtl_val':precision_mtl_val_ii_ml, 'precision_mtl_test':precision_mtl_test_ii_ml,
            'recall_mtl_val':recall_mtl_val_ii_ml, 'recall_mtl_test':recall_mtl_test_ii_ml})

# %%
models_results_df
# Out:
#     epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0        1          0.750545           0.753816          0.464875
# 1        2          0.819717           0.820896          0.539897
# 2        3          0.826525           0.822405          0.548693
# 3        4          0.830338           0.828558          0.564900
# 4        5          0.827887           0.829855          0.562577
# 5        6          0.837328           0.841135          0.578066
# 6        7          0.824437           0.827261          0.580017
# 7        8          0.844953           0.837908          0.585453
# 8        9          0.843682           0.839597          0.585070
# 9       10          0.847767           0.844272          0.597716
# 10      11          0.827342           0.821530          0.569020
# 11      12          0.839234           0.838149          0.586619
# 12      13          0.834423           0.834922          0.584148
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.847767           0.844272          0.597716
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.593155           0.770678            0.763035        0.488159
#
#    recall_mtl_test
# 9         0.485144

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont_20_epochs/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont_20_epochs/train.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, loss_ii_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, loss_ii_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_ii_mc)+np.array(loss_ii_ml)
loss_val = np.array(loss_val_ii_mc)+np.array(loss_val_ii_ml)
loss_test = np.array(loss_test_ii_mc)+np.array(loss_test_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_ii_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Full (the ontology contains all relations between entities)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_full_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_full_ont/val.multilabel_metrics'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ebb836b8eebd> in <module>()
# ----> 1 mtl_val_results_multiclass = ont_dir + 'food_multitask_full_ont/val.multiclass_metrics'
#       2 mtl_val_results_multilabel = ont_dir + 'food_multitask_full_ont/val.multilabel_metrics'
#
# NameError: name 'ont_dir' is not defined

# %%
epoch_mtl_val_full_mc, accuracy_mtl_val_full_mc, balanced_accuracy_mtl_val_full_mc, loss_val_full_mc, f1_mtl_val_full_mc, precision_mtl_val_full_mc, recall_mtl_val_full_mc, \
epoch_mtl_val_full_ml, average_precision_mtl_val_full_ml, loss_val_full_ml, coverage_error_mtl_val_full_ml, f1_mtl_val_full_ml, precision_mtl_val_full_ml, \
ranking_loss_mtl_val_full_ml, recall_mtl_val_full_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2596cb86ea56> in <module>()
# ----> 1 epoch_mtl_val_full_mc, accuracy_mtl_val_full_mc, balanced_accuracy_mtl_val_full_mc, loss_val_full_mc, f1_mtl_val_full_mc, precision_mtl_val_full_mc, recall_mtl_val_full_mc, epoch_mtl_val_full_ml, average_precision_mtl_val_full_ml, loss_val_full_ml, coverage_error_mtl_val_full_ml, f1_mtl_val_full_ml, precision_mtl_val_full_ml, ranking_loss_mtl_val_full_ml, recall_mtl_val_full_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)
#
# NameError: name 'mtl_val_results_multiclass' is not defined

# %%
dr.plot_metrics(epoch_mtl_val_full_mc, accuracy_mtl_val_full_mc, epoch_mtl_val_full_ml, f1_mtl_val_full_ml, precision_mtl_val_full_ml, recall_mtl_val_full_ml, 'Full')

# %% [markdown]
# #### Evaluation over test set

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_full_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_full_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_full_mc, accuracy_mtl_test_full_mc, balanced_accuracy_mtl_test_full_mc, loss_test_full_mc, f1_mtl_test_full_mc, precision_mtl_test_full_mc, recall_mtl_test_full_mc, \
epoch_mtl_test_full_ml, average_precision_mtl_test_full_ml, loss_test_full_ml, coverage_error_mtl_test_full_ml, f1_mtl_test_full_ml, precision_mtl_test_full_ml, \
ranking_loss_mtl_test_full_ml, recall_mtl_test_full_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_full_mc,
            'accuracy_mtl_val':accuracy_mtl_val_full_mc,'accuracy_mtl_test':accuracy_mtl_test_full_mc,
            'f1-score_mtl_val':f1_mtl_val_full_ml,'f1-score_mtl_test':f1_mtl_test_full_ml,
            'precision_mtl_val':precision_mtl_val_full_ml, 'precision_mtl_test':precision_mtl_test_full_ml,
            'recall_mtl_val':recall_mtl_val_full_ml, 'recall_mtl_test':recall_mtl_test_full_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.768700           0.758822          0.334142
# 1       2          0.806463           0.802166          0.358040
# 2       3          0.816903           0.814713          0.378252
# 3       4          0.817901           0.816251          0.381095
# 4       5          0.826888           0.820504          0.385647
# 5       6          0.833787           0.827653          0.395646
# 6       7          0.830428           0.827442          0.406110
# 7       8          0.827524           0.827954          0.410666
# 8       9          0.806282           0.801502          0.408619
# 9      10          0.832970           0.828980          0.424773
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.335413           0.428942            0.431156        0.273660
# 1           0.362682           0.488704            0.496574        0.282507
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10           0.83297            0.82898          0.424773
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.425442           0.514467            0.512113         0.36171
#
#    recall_mtl_test
# 9         0.363861

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_full_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_full_ont/train.multilabel_metrics'

# %%
epoch_mtl_full_mc, accuracy_mtl_full_mc, balanced_accuracy_mtl_full_mc, loss_full_mc, f1_mtl_full_mc, precision_mtl_full_mc, recall_mtl_full_mc, \
epoch_mtl_full_ml, average_precision_mtl_full_ml, loss_full_ml, coverage_error_mtl_full_ml, f1_mtl_full_ml, precision_mtl_full_ml, \
ranking_loss_mtl_full_ml, recall_mtl_full_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_full_mc)+np.array(loss_full_ml)
loss_val = np.array(loss_val_full_mc)+np.array(loss_val_full_ml)
loss_test = np.array(loss_test_full_mc)+np.array(loss_test_full_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_full_mc, loss, label='train_loss')
ax.plot(epoch_mtl_full_mc, loss_val, label='val_loss')
ax.legend()

# %%
dr.plot_metrics(epoch_mtl_val_full_mc, accuracy_mtl_val_full_mc, epoch_mtl_val_full_ml, f1_mtl_val_full_ml, precision_mtl_val_full_ml, recall_mtl_val_full_ml, 'Full')

# %% [markdown]
# ### Ontology_prob_neg (elements of the matrix are probabilities and negatives relations)

# %%
ont_dir = results_dir + 'Ontology_prob_neg/'

# %% [markdown]
# #### Dish-Ingredient (the ontology contains the top-down relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, balanced_accuracy_mtl_val_di_mc, loss_val_di_mc, f1_mtl_val_di_mc, precision_mtl_val_di_mc, recall_mtl_val_di_mc, \
epoch_mtl_val_di_ml, average_precision_mtl_val_di_ml, loss_val_di_ml, coverage_error_mtl_val_di_ml, f1_mtl_val_di_ml, precision_mtl_val_di_ml, \
ranking_loss_mtl_val_di_ml, recall_mtl_val_di_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, balanced_accuracy_mtl_test_di_mc, loss_test_di_mc, f1_mtl_test_di_mc, precision_mtl_test_di_mc, recall_mtl_test_di_mc, \
epoch_mtl_test_di_ml, average_precision_mtl_test_di_ml, loss_test_di_ml, coverage_error_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, \
ranking_loss_mtl_test_di_ml, recall_mtl_test_di_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, accuracy_mtl_test_di_mc, epoch_mtl_val_di_ml,
                f1_mtl_val_di_ml, f1_mtl_test_di_ml, precision_mtl_val_di_ml, precision_mtl_test_di_ml, recall_mtl_val_di_ml, recall_mtl_test_di_ml, 'Dish-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_mc,'accuracy_mtl_test':accuracy_mtl_test_di_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ml,'f1-score_mtl_test':f1_mtl_test_di_ml,
            'precision_mtl_val':precision_mtl_val_di_ml, 'precision_mtl_test':precision_mtl_test_di_ml,
            'recall_mtl_val':recall_mtl_val_di_ml, 'recall_mtl_test':recall_mtl_test_di_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.746187           0.746275          0.592593
# 1       2          0.798384           0.798033          0.626494
# 2       3          0.820988           0.821138          0.652285
# 3       4          0.820443           0.817910          0.653713
# 4       5          0.842048           0.841769          0.668870
# 5       6          0.808370           0.801743          0.645522
# 6       7          0.841594           0.841678          0.669806
# 7       8          0.836692           0.836943          0.667440
# 8       9          0.842320           0.841075          0.676892
# 9      10          0.851126           0.848284          0.687330
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.587043           0.673720            0.668942        0.528904
# 1           0.623746           0.680387            0.677894        0.580512
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.851126           0.848284           0.68733
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9            0.68314           0.756681            0.751113        0.629623
#
#    recall_mtl_test
# 9         0.626449

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, loss_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, loss_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_di_mc)+np.array(loss_val_di_ml)
loss_test = np.array(loss_test_di_mc)+np.array(loss_test_di_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Ingredient-Dish (the ontology contains the bottom-up relation between dishes and ingredients)

# %%
#Validation Set
mtl_val_results_multiclass = ont_dir + 'food_multitask_ingr_dish_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_ingr_dish_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_id_mc, accuracy_mtl_val_id_mc, balanced_accuracy_mtl_val_id_mc, loss_val_id_mc, f1_mtl_val_id_mc, precision_mtl_val_id_mc, recall_mtl_val_id_mc, \
epoch_mtl_val_id_ml, average_precision_mtl_val_id_ml, loss_val_id_ml, coverage_error_mtl_val_id_ml, f1_mtl_val_id_ml, precision_mtl_val_id_ml, \
ranking_loss_mtl_val_id_ml, recall_mtl_val_id_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
#Test Set
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_dish_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_id_mc, accuracy_mtl_test_id_mc, balanced_accuracy_mtl_test_id_mc, loss_test_id_mc, f1_mtl_test_id_mc, precision_mtl_test_id_mc, recall_mtl_test_id_mc, \
epoch_mtl_test_id_ml, average_precision_mtl_test_id_ml, loss_test_id_ml, coverage_error_mtl_test_id_ml, f1_mtl_test_id_ml, precision_mtl_test_id_ml, \
ranking_loss_mtl_test_id_ml, recall_mtl_test_id_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_id_mc, accuracy_mtl_val_id_mc, accuracy_mtl_test_id_mc, epoch_mtl_val_id_ml,
                f1_mtl_val_id_ml, f1_mtl_test_id_ml, precision_mtl_val_id_ml, precision_mtl_test_id_ml, recall_mtl_val_id_ml, recall_mtl_test_id_ml, 'Ingredient-Dish')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_id_mc,
            'accuracy_mtl_val':accuracy_mtl_val_id_mc,'accuracy_mtl_test':accuracy_mtl_test_id_mc,
            'f1-score_mtl_val':f1_mtl_val_id_ml,'f1-score_mtl_test':f1_mtl_test_id_ml,
            'precision_mtl_val':precision_mtl_val_id_ml, 'precision_mtl_test':precision_mtl_test_id_ml,
            'recall_mtl_val':recall_mtl_val_id_ml, 'recall_mtl_test':recall_mtl_test_id_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.768337           0.768987          0.386379
# 1       2          0.809277           0.805453          0.426710
# 2       3          0.818446           0.819841          0.461176
# 3       4          0.834695           0.832569          0.488725
# 4       5          0.832879           0.829794          0.509078
# 5       6          0.840142           0.843036          0.544509
# 6       7          0.830701           0.827653          0.549350
# 7       8          0.833606           0.831544          0.548215
# 8       9          0.841866           0.840019          0.564797
# 9      10          0.837328           0.837244          0.580441
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.386360           0.515910            0.516141        0.308838
# 1           0.423803           0.653345            0.650460        0.316813
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.837328           0.837244          0.580441
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9            0.57565            0.77711            0.776306        0.463212
#
#    recall_mtl_test
# 9         0.457419

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_dish_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_dish_ont/train.multilabel_metrics'

# %%
epoch_mtl_id_mc, accuracy_mtl_id_mc, balanced_accuracy_mtl_id_mc, loss_id_mc, f1_mtl_id_mc, precision_mtl_id_mc, recall_mtl_id_mc, \
epoch_mtl_id_ml, average_precision_mtl_id_ml, loss_id_ml, coverage_error_mtl_id_ml, f1_mtl_id_ml, precision_mtl_id_ml, \
ranking_loss_mtl_id_ml, recall_mtl_id_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
#Train-Val Loss
loss = np.array(loss_id_mc)+np.array(loss_id_ml)
loss_val = np.array(loss_val_id_mc)+np.array(loss_val_id_ml)
loss_test = np.array(loss_test_id_mc)+np.array(loss_test_id_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_id_mc, loss, label='train_loss')
ax.plot(epoch_mtl_id_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Dish-Ingredient_Ingredient-Dish (the ontology contains the top-down and bottom-up relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_id_mc, accuracy_mtl_val_di_id_mc, balanced_accuracy_mtl_val_di_id_mc, loss_val_di_id_mc, f1_mtl_val_di_id_mc, precision_mtl_val_di_id_mc, recall_mtl_val_di_id_mc, \
epoch_mtl_val_di_id_ml, average_precision_mtl_val_di_id_ml, loss_val_di_id_ml, coverage_error_mtl_val_di_id_ml, f1_mtl_val_di_id_ml, precision_mtl_val_di_id_ml, \
ranking_loss_mtl_val_di_id_ml, recall_mtl_val_di_id_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_id_mc, accuracy_mtl_test_di_id_mc, balanced_accuracy_mtl_test_di_id_mc, loss_test_di_id_mc, f1_mtl_test_di_id_mc, precision_mtl_test_di_id_mc, recall_mtl_test_di_id_mc, \
epoch_mtl_test_di_id_ml, average_precision_mtl_test_di_id_ml, loss_test_di_id_ml, coverage_error_mtl_test_di_id_ml, f1_mtl_test_di_id_ml, precision_mtl_test_di_id_ml, \
ranking_loss_mtl_test_di_id_ml, recall_mtl_test_di_id_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_id_mc, accuracy_mtl_val_di_id_mc, accuracy_mtl_test_di_id_mc, epoch_mtl_val_di_id_ml,
                f1_mtl_val_di_id_ml, f1_mtl_test_di_id_ml, precision_mtl_val_di_id_ml, precision_mtl_test_di_id_ml, recall_mtl_val_di_id_ml, recall_mtl_test_di_id_ml, 'Dish-Ingredient Ingredient-Dish')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_id_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_id_mc,'accuracy_mtl_test':accuracy_mtl_test_di_id_mc,
            'f1-score_mtl_val':f1_mtl_val_di_id_ml,'f1-score_mtl_test':f1_mtl_test_di_id_ml,
            'precision_mtl_val':precision_mtl_val_di_id_ml, 'precision_mtl_test':precision_mtl_test_di_id_ml,
            'recall_mtl_val':recall_mtl_val_di_id_ml, 'recall_mtl_test':recall_mtl_test_di_id_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.762981           0.758641          0.356950
# 1       2          0.788489           0.790282          0.469622
# 2       3          0.820806           0.821681          0.520877
# 3       4          0.808551           0.805272          0.533628
# 4       5          0.818537           0.816674          0.543994
# 5       6          0.814906           0.815709          0.557511
# 6       7          0.829430           0.824244          0.580052
# 7       8          0.822712           0.819087          0.577121
# 8       9          0.840142           0.839084          0.589874
# 9      10          0.830973           0.825059          0.585774
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.357481           0.256199            0.256489        0.588306
# 1           0.468720           0.395900            0.396325        0.577082
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 8       9          0.840142           0.839084          0.589874
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 8           0.587779           0.613122            0.609055        0.568325
#
#    recall_mtl_test
# 8         0.567939

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_dish_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, balanced_accuracy_mtl_di_id_mc, loss_di_id_mc, f1_mtl_di_id_mc, precision_mtl_di_id_mc, recall_mtl_di_id_mc, \
epoch_mtl_di_id_ml, average_precision_mtl_di_id_ml, loss_di_id_ml, coverage_error_mtl_di_id_ml, f1_mtl_di_id_ml, precision_mtl_di_id_ml, \
ranking_loss_mtl_di_id_ml, recall_mtl_di_id_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_id_mc)+np.array(loss_di_id_ml)
loss_val = np.array(loss_val_di_id_mc)+np.array(loss_val_di_id_ml)
loss_test = np.array(loss_test_di_id_mc)+np.array(loss_test_di_id_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_id_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_id_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Dish-Ingredient Ingredient-Ingredient (the ontology contains the bottom-up relation between dishes and ingredients, and pair coexistence relation ingredient)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_ii_mc, accuracy_mtl_val_di_ii_mc, balanced_accuracy_mtl_val_di_ii_mc, loss_val_di_ii_mc, f1_mtl_val_di_ii_mc, precision_mtl_val_di_ii_mc, recall_mtl_val_di_ii_mc, \
epoch_mtl_val_di_ii_ml, average_precision_mtl_val_di_ii_ml, loss_val_di_ii_ml, coverage_error_mtl_val_di_ii_ml, f1_mtl_val_di_ii_ml, precision_mtl_val_di_ii_ml, \
ranking_loss_mtl_val_di_ii_ml, recall_mtl_val_di_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_ii_mc, accuracy_mtl_test_di_ii_mc, balanced_accuracy_mtl_test_di_ii_mc, loss_test_di_ii_mc, f1_mtl_test_di_ii_mc, precision_mtl_test_di_ii_mc, recall_mtl_test_di_ii_mc, \
epoch_mtl_test_di_ii_ml, average_precision_mtl_test_di_ii_ml, loss_test_di_ii_ml, coverage_error_mtl_test_di_ii_ml, f1_mtl_test_di_ii_ml, precision_mtl_test_di_ii_ml, \
ranking_loss_mtl_test_di_ii_ml, recall_mtl_test_di_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_ii_mc, accuracy_mtl_val_di_ii_mc, accuracy_mtl_test_di_ii_mc, epoch_mtl_val_di_ii_ml, f1_mtl_val_di_ii_ml, f1_mtl_test_di_ii_ml,
                precision_mtl_val_di_ii_ml, precision_mtl_test_di_ii_ml, recall_mtl_val_di_ii_ml, recall_mtl_test_di_ii_ml, 'Dish-Ingredient Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_di_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ii_ml,'f1-score_mtl_test':f1_mtl_test_di_ii_ml,
            'precision_mtl_val':precision_mtl_val_di_ii_ml, 'precision_mtl_test':precision_mtl_test_di_ii_ml,
            'recall_mtl_val':recall_mtl_val_di_ii_ml, 'recall_mtl_test':recall_mtl_test_di_ii_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.756990           0.760572          0.570687
# 1       2          0.795842           0.802196          0.620584
# 2       3          0.815359           0.818061          0.640096
# 3       4          0.834877           0.832841          0.662752
# 4       5          0.840686           0.843156          0.670066
# 5       6          0.847313           0.845328          0.673680
# 6       7          0.816358           0.816855          0.641596
# 7       8          0.845951           0.840502          0.683932
# 8       9          0.843682           0.836943          0.680026
# 9      10          0.851852           0.852205          0.688621
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.570732           0.726317            0.726835        0.469983
# 1           0.616134           0.758299            0.754583        0.525202
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.851852           0.852205          0.688621
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9            0.68931           0.762199            0.759954        0.627998
#
#    recall_mtl_test
# 9         0.630683

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_ii_mc, accuracy_mtl_di_ii_mc, balanced_accuracy_mtl_di_ii_mc, loss_di_ii_mc, f1_mtl_di_ii_mc, precision_mtl_di_ii_mc, recall_mtl_di_ii_mc, \
epoch_mtl_di_ii_ml, average_precision_mtl_di_ii_ml, loss_di_ii_ml, coverage_error_mtl_di_ii_ml, f1_mtl_di_ii_ml, precision_mtl_di_ii_ml, \
ranking_loss_mtl_di_ii_ml, recall_mtl_di_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_ii_mc)+np.array(loss_di_ii_ml)
loss_val = np.array(loss_val_di_ii_mc)+np.array(loss_val_di_ii_ml)
loss_test = np.array(loss_test_di_ii_mc)+np.array(loss_test_di_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_ii_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Ingredient-Ingredient (the ontology contains the coexistence relation between ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, balanced_accuracy_mtl_val_ii_mc, loss_val_ii_mc, f1_mtl_val_ii_mc, precision_mtl_val_ii_mc, recall_mtl_val_ii_mc, \
epoch_mtl_val_ii_ml, average_precision_mtl_val_ii_ml, loss_val_ii_ml, coverage_error_mtl_val_ii_ml, f1_mtl_val_ii_ml, precision_mtl_val_ii_ml, \
ranking_loss_mtl_val_ii_ml, recall_mtl_val_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_ii_mc, accuracy_mtl_test_ii_mc, balanced_accuracy_mtl_test_ii_mc, loss_test_ii_mc, f1_mtl_test_ii_mc, precision_mtl_test_ii_mc, recall_mtl_test_ii_mc, \
epoch_mtl_test_ii_ml, average_precision_mtl_test_ii_ml, loss_test_ii_ml, coverage_error_mtl_test_ii_ml, f1_mtl_test_ii_ml, precision_mtl_test_ii_ml, \
ranking_loss_mtl_test_ii_ml, recall_mtl_test_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, accuracy_mtl_test_ii_mc, epoch_mtl_val_ii_ml,
                f1_mtl_val_ii_ml, f1_mtl_test_ii_ml, precision_mtl_val_ii_ml, precision_mtl_test_ii_ml, recall_mtl_val_ii_ml, recall_mtl_test_ii_ml, 'Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_ii_ml,'f1-score_mtl_test':f1_mtl_test_ii_ml,
            'precision_mtl_val':precision_mtl_val_ii_ml, 'precision_mtl_test':precision_mtl_test_ii_ml,
            'recall_mtl_val':recall_mtl_val_ii_ml, 'recall_mtl_test':recall_mtl_test_ii_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.764161           0.763045          0.530604
# 1       2          0.787582           0.789528          0.619490
# 2       3          0.813635           0.815256          0.622959
# 3       4          0.827160           0.826778          0.637023
# 4       5          0.835784           0.837848          0.659773
# 5       6          0.835330           0.833685          0.659860
# 6       7          0.840868           0.843850          0.671351
# 7       8          0.842956           0.841739          0.667329
# 8       9          0.821532           0.823249          0.646914
# 9      10          0.854031           0.849249          0.682266
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.526422           0.731722            0.726841        0.416208
# 1           0.613426           0.713429            0.707511        0.547411
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.854031           0.849249          0.682266
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.681567           0.788108            0.789324        0.601487
#
#    recall_mtl_test
# 9         0.599697

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, loss_ii_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, loss_ii_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_ii_mc)+np.array(loss_ii_ml)
loss_val = np.array(loss_val_ii_mc)+np.array(loss_val_ii_ml)
loss_test = np.array(loss_test_ii_mc)+np.array(loss_test_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_ii_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Full (the ontology contains all relations between entities)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_full_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_full_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_full_mc, accuracy_mtl_val_full_mc, balanced_accuracy_mtl_val_full_mc, loss_val_full_mc, f1_mtl_val_full_mc, precision_mtl_val_full_mc, recall_mtl_val_full_mc, \
epoch_mtl_val_full_ml, average_precision_mtl_val_full_ml, loss_val_full_ml, coverage_error_mtl_val_full_ml, f1_mtl_val_full_ml, precision_mtl_val_full_ml, \
ranking_loss_mtl_val_full_ml, recall_mtl_val_full_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_full_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_full_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_full_mc, accuracy_mtl_test_full_mc, balanced_accuracy_mtl_test_full_mc, loss_test_full_mc, f1_mtl_test_full_mc, precision_mtl_test_full_mc, recall_mtl_test_full_mc, \
epoch_mtl_test_full_ml, average_precision_mtl_test_full_ml, loss_test_full_ml, coverage_error_mtl_test_full_ml, f1_mtl_test_full_ml, precision_mtl_test_full_ml, \
ranking_loss_mtl_test_full_ml, recall_mtl_test_full_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_full_mc, accuracy_mtl_val_full_mc, accuracy_mtl_test_full_mc, epoch_mtl_val_full_ml,
                f1_mtl_val_full_ml, f1_mtl_test_full_ml, precision_mtl_val_full_ml, precision_mtl_test_full_ml, recall_mtl_val_full_ml, recall_mtl_test_full_ml, 'Full')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_full_mc,
            'accuracy_mtl_val':accuracy_mtl_val_full_mc,'accuracy_mtl_test':accuracy_mtl_test_full_mc,
            'f1-score_mtl_val':f1_mtl_val_full_ml,'f1-score_mtl_test':f1_mtl_test_full_ml,
            'precision_mtl_val':precision_mtl_val_full_ml, 'precision_mtl_test':precision_mtl_test_full_ml,
            'recall_mtl_val':recall_mtl_val_full_ml, 'recall_mtl_test':recall_mtl_test_full_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.778322           0.775894          0.523408
# 1       2          0.808824           0.808077          0.566291
# 2       3          0.804103           0.803312          0.563476
# 3       4          0.828522           0.827683          0.596741
# 4       5          0.822712           0.823068          0.609544
# 5       6          0.835784           0.834138          0.615411
# 6       7          0.836692           0.840532          0.616339
# 7       8          0.818809           0.815799          0.626497
# 8       9          0.799655           0.800477          0.608178
# 9      10          0.842593           0.843307          0.628113
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.521729           0.559281            0.554891        0.491860
# 1           0.562604           0.612634            0.606671        0.526466
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.842593           0.843307          0.628113
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.624165           0.661277            0.656286        0.598116
#
#    recall_mtl_test
# 9         0.595043

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_full_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_full_ont/train.multilabel_metrics'

# %%
epoch_mtl_full_mc, accuracy_mtl_full_mc, balanced_accuracy_mtl_full_mc, loss_full_mc, f1_mtl_full_mc, precision_mtl_full_mc, recall_mtl_full_mc, \
epoch_mtl_full_ml, average_precision_mtl_full_ml, loss_full_ml, coverage_error_mtl_full_ml, f1_mtl_full_ml, precision_mtl_full_ml, \
ranking_loss_mtl_full_ml, recall_mtl_full_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_full_mc)+np.array(loss_full_ml)
loss_val = np.array(loss_val_full_mc)+np.array(loss_val_full_ml)
loss_test = np.array(loss_test_full_mc)+np.array(loss_test_full_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_full_mc, loss, label='train_loss')
ax.plot(epoch_mtl_full_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# ### Two Ontology Layers prob (first fixed, second fine-tunning)

# %%
ont_dir = results_dir + 'Two_Ontology_prob/'

# %% [markdown]
# #### Dish-Ingredient (the ontology contains the top-down relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, balanced_accuracy_mtl_val_di_mc, loss_val_di_mc, f1_mtl_val_di_mc, precision_mtl_val_di_mc, recall_mtl_val_di_mc, \
epoch_mtl_val_di_ml, average_precision_mtl_val_di_ml, loss_val_di_ml, coverage_error_mtl_val_di_ml, f1_mtl_val_di_ml, precision_mtl_val_di_ml, \
ranking_loss_mtl_val_di_ml, recall_mtl_val_di_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, balanced_accuracy_mtl_test_di_mc, loss_test_di_mc, f1_mtl_test_di_mc, precision_mtl_test_di_mc, recall_mtl_test_di_mc, \
epoch_mtl_test_di_ml, average_precision_mtl_test_di_ml, loss_test_di_ml, coverage_error_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, \
ranking_loss_mtl_test_di_ml, recall_mtl_test_di_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, accuracy_mtl_test_di_mc, epoch_mtl_val_di_ml,
                f1_mtl_val_di_ml, f1_mtl_test_di_ml, precision_mtl_val_di_ml, precision_mtl_test_di_ml, recall_mtl_val_di_ml, recall_mtl_test_di_ml, 'Dish-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_mc,'accuracy_mtl_test':accuracy_mtl_test_di_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ml,'f1-score_mtl_test':f1_mtl_test_di_ml,
            'precision_mtl_val':precision_mtl_val_di_ml, 'precision_mtl_test':precision_mtl_test_di_ml,
            'recall_mtl_val':recall_mtl_val_di_ml, 'recall_mtl_test':recall_mtl_test_di_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.753177           0.757465          0.583865
# 1       2          0.796387           0.796224          0.612678
# 2       3          0.797476           0.793690          0.612147
# 3       4          0.785040           0.785637          0.597696
# 4       5          0.827887           0.828437          0.632116
# 5       6          0.825527           0.825843          0.654553
# 6       7          0.813816           0.814080          0.638672
# 7       8          0.833152           0.835254          0.654591
# 8       9          0.815632           0.816644          0.636557
# 9      10          0.804648           0.807746          0.640791
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.580558           0.716549            0.713796        0.492642
# 1           0.609532           0.749369            0.749250        0.518161
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 7       8          0.833152           0.835254          0.654591
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 7           0.652268            0.76799            0.767544        0.570371
#
#    recall_mtl_test
# 7         0.567097

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, loss_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, loss_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_di_mc)+np.array(loss_val_di_ml)
loss_test = np.array(loss_test_di_mc)+np.array(loss_test_di_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# ### Two Ontologies probabilities negative (first layer fixed, second trainable)

# %%
ont_dir = results_dir + 'Two_Ontology_prob_neg/'

# %% [markdown]
# #### Dish-Ingredient (the ontology contains the top-down relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, balanced_accuracy_mtl_val_di_mc, loss_val_di_mc, f1_mtl_val_di_mc, precision_mtl_val_di_mc, recall_mtl_val_di_mc, \
epoch_mtl_val_di_ml, average_precision_mtl_val_di_ml, loss_val_di_ml, coverage_error_mtl_val_di_ml, f1_mtl_val_di_ml, precision_mtl_val_di_ml, \
ranking_loss_mtl_val_di_ml, recall_mtl_val_di_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, balanced_accuracy_mtl_test_di_mc, loss_test_di_mc, f1_mtl_test_di_mc, precision_mtl_test_di_mc, recall_mtl_test_di_mc, \
epoch_mtl_test_di_ml, average_precision_mtl_test_di_ml, loss_test_di_ml, coverage_error_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, \
ranking_loss_mtl_test_di_ml, recall_mtl_test_di_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, accuracy_mtl_test_di_mc, epoch_mtl_val_di_ml,
                f1_mtl_val_di_ml, f1_mtl_test_di_ml, precision_mtl_val_di_ml, precision_mtl_test_di_ml, recall_mtl_val_di_ml, recall_mtl_test_di_ml, 'Dish-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_mc,'accuracy_mtl_test':accuracy_mtl_test_di_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ml,'f1-score_mtl_test':f1_mtl_test_di_ml,
            'precision_mtl_val':precision_mtl_val_di_ml, 'precision_mtl_test':precision_mtl_test_di_ml,
            'recall_mtl_val':recall_mtl_val_di_ml, 'recall_mtl_test':recall_mtl_test_di_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.778958           0.775683          0.605792
# 1       2          0.791848           0.793660          0.621850
# 2       3          0.790396           0.789678          0.622505
# 3       4          0.800744           0.793931          0.612774
# 4       5          0.828885           0.826265          0.653422
# 5       6          0.801198           0.798214          0.617243
# 6       7          0.814270           0.814442          0.627512
# 7       8          0.825890           0.818996          0.636636
# 8       9          0.826888           0.823581          0.655078
# 9      10          0.821714           0.816553          0.649315
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.602058           0.664666            0.661265        0.556498
# 1           0.621104           0.627946            0.628363        0.615871
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 8       9          0.826888           0.823581          0.655078
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 8           0.652133           0.704934              0.7023        0.611808
#
#    recall_mtl_test
# 8         0.608655

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, loss_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, loss_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_di_mc)+np.array(loss_val_di_ml)
loss_test = np.array(loss_test_di_mc)+np.array(loss_test_di_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Ingredient-Ingredient (the ontology contains the coexistence relation between ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, balanced_accuracy_mtl_val_ii_mc, loss_val_ii_mc, f1_mtl_val_ii_mc, precision_mtl_val_ii_mc, recall_mtl_val_ii_mc, \
epoch_mtl_val_ii_ml, average_precision_mtl_val_ii_ml, loss_val_ii_ml, coverage_error_mtl_val_ii_ml, f1_mtl_val_ii_ml, precision_mtl_val_ii_ml, \
ranking_loss_mtl_val_ii_ml, recall_mtl_val_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_ii_mc, accuracy_mtl_test_ii_mc, balanced_accuracy_mtl_test_ii_mc, loss_test_ii_mc, f1_mtl_test_ii_mc, precision_mtl_test_ii_mc, recall_mtl_test_ii_mc, \
epoch_mtl_test_ii_ml, average_precision_mtl_test_ii_ml, loss_test_ii_ml, coverage_error_mtl_test_ii_ml, f1_mtl_test_ii_ml, precision_mtl_test_ii_ml, \
ranking_loss_mtl_test_ii_ml, recall_mtl_test_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, accuracy_mtl_test_ii_mc, epoch_mtl_val_ii_ml,
                f1_mtl_val_ii_ml, f1_mtl_test_ii_ml, precision_mtl_val_ii_ml, precision_mtl_test_ii_ml, recall_mtl_val_ii_ml, recall_mtl_test_ii_ml, 'Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_ii_ml,'f1-score_mtl_test':f1_mtl_test_ii_ml,
            'precision_mtl_val':precision_mtl_val_ii_ml, 'precision_mtl_test':precision_mtl_test_ii_ml,
            'recall_mtl_val':recall_mtl_val_ii_ml, 'recall_mtl_test':recall_mtl_test_ii_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.763526           0.761085          0.525695
# 1       2          0.792847           0.790644          0.553430
# 2       3          0.823166           0.819780          0.561964
# 3       4          0.803649           0.805453          0.581502
# 4       5          0.812455           0.812421          0.623309
# 5       6          0.834060           0.829402          0.647462
# 6       7          0.806463           0.804006          0.624827
# 7       8          0.801380           0.804006          0.625766
# 8       9          0.820897           0.825572          0.623138
# 9      10          0.501543           0.502624          0.360101
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.517088           0.586427            0.578397        0.476362
# 1           0.549754           0.703401            0.699888        0.456170
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 5       6           0.83406           0.829402          0.647462
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 5           0.644313           0.739865            0.737087        0.575577
#
#    recall_mtl_test
# 5         0.572283

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, loss_di_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, loss_di_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_ii_mc)+np.array(loss_val_ii_ml)
loss_test = np.array(loss_test_ii_mc)+np.array(loss_test_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_ii_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Dish-Ingredient Ingredient-Ingredient

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_ii_mc, accuracy_mtl_val_di_ii_mc, balanced_accuracy_mtl_val_di_ii_mc, loss_val_di_ii_mc, f1_mtl_val_di_ii_mc, precision_mtl_val_di_ii_mc, recall_mtl_val_di_ii_mc, \
epoch_mtl_val_di_ii_ml, average_precision_mtl_val_di_ii_ml, loss_val_di_ii_ml, coverage_error_mtl_val_di_ii_ml, f1_mtl_val_di_ii_ml, precision_mtl_val_di_ii_ml, \
ranking_loss_mtl_val_di_ii_ml, recall_mtl_val_di_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_ii_mc, accuracy_mtl_test_di_ii_mc, balanced_accuracy_mtl_test_di_ii_mc, loss_test_di_ii_mc, f1_mtl_test_di_ii_mc, precision_mtl_test_di_ii_mc, recall_mtl_test_di_ii_mc, \
epoch_mtl_test_di_ii_ml, average_precision_mtl_test_di_ii_ml, loss_test_di_ii_ml, coverage_error_mtl_test_di_ii_ml, f1_mtl_test_di_ii_ml, precision_mtl_test_di_ii_ml, \
ranking_loss_mtl_test_di_ii_ml, recall_mtl_test_di_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_ii_mc, accuracy_mtl_val_di_ii_mc, accuracy_mtl_test_di_ii_mc, epoch_mtl_val_di_ii_ml,
                f1_mtl_val_di_ii_ml, f1_mtl_test_di_ii_ml, precision_mtl_val_di_ii_ml, precision_mtl_test_di_ii_ml, recall_mtl_val_di_ii_ml, recall_mtl_test_di_ii_ml, 'Dish-Ingredient Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_di_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ii_ml,'f1-score_mtl_test':f1_mtl_test_di_ii_ml,
            'precision_mtl_val':precision_mtl_val_di_ii_ml, 'precision_mtl_test':precision_mtl_test_di_ii_ml,
            'recall_mtl_val':recall_mtl_val_di_ii_ml, 'recall_mtl_test':recall_mtl_test_di_ii_ml})

# %%
models_results_df
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 0       1          0.763707           0.764583          0.547870
# 1       2          0.795116           0.790372          0.566228
# 2       3          0.791122           0.790885          0.589185
# 3       4          0.809822           0.811244          0.590270
# 4       5          0.829702           0.831845          0.638419
# 5       6          0.818446           0.813959          0.634982
# 6       7          0.833424           0.826899          0.638356
# 7       8          0.819081           0.815226          0.617182
# 8       9          0.814906           0.811938          0.644557
# 9      10          0.822259           0.820082          0.649687
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 0           0.546333           0.665906            0.662125        0.465379
# 1           0.563034           0.513831            0.509632        0.630526
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    epochs  accuracy_mtl_val  accuracy_mtl_test  f1-score_mtl_val  \
# 9      10          0.822259           0.820082          0.649687
#
#    f1-score_mtl_test  precision_mtl_val  precision_mtl_test  recall_mtl_val  \
# 9           0.648151           0.681639             0.67802        0.620595
#
#    recall_mtl_test
# 9         0.620802

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_ii_mc, accuracy_mtl_di_ii_mc, balanced_accuracy_mtl_di_ii_mc, loss_di_ii_mc, f1_mtl_di_ii_mc, precision_mtl_di_ii_mc, recall_mtl_di_ii_mc, \
epoch_mtl_di_ii_ml, average_precision_mtl_di_ii_ml, loss_di_ii_ml, coverage_error_mtl_di_ii_ml, f1_mtl_di_ii_ml, precision_mtl_di_ii_ml, \
ranking_loss_mtl_di_ii_ml, recall_mtl_di_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_ii_mc)+np.array(loss_di_ii_ml)
loss_val = np.array(loss_val_di_ii_mc)+np.array(loss_val_di_ii_ml)
loss_test = np.array(loss_test_di_ii_mc)+np.array(loss_test_di_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_ii_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# ### Two Ontology Layers prob (fine-tunning)

# %%
ont_dir = results_dir + 'Two_Ontology_prob_v2/'

# %% [markdown]
# #### Dish-Ingredient (the ontology contains the top-down relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, balanced_accuracy_mtl_val_di_mc, loss_val_di_mc, f1_mtl_val_di_mc, precision_mtl_val_di_mc, recall_mtl_val_di_mc, \
epoch_mtl_val_di_ml, average_precision_mtl_val_di_ml, loss_val_di_ml, coverage_error_mtl_val_di_ml, f1_mtl_val_di_ml, precision_mtl_val_di_ml, \
ranking_loss_mtl_val_di_ml, recall_mtl_val_di_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, balanced_accuracy_mtl_test_di_mc, loss_test_di_mc, f1_mtl_test_di_mc, precision_mtl_test_di_mc, recall_mtl_test_di_mc, \
epoch_mtl_test_di_ml, average_precision_mtl_test_di_ml, loss_test_di_ml, coverage_error_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, \
ranking_loss_mtl_test_di_ml, recall_mtl_test_di_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, accuracy_mtl_test_di_mc, epoch_mtl_val_di_ml,
                f1_mtl_val_di_ml, f1_mtl_test_di_ml, precision_mtl_val_di_ml, precision_mtl_test_di_ml, recall_mtl_val_di_ml, recall_mtl_test_di_ml, 'Dish-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_mc,'accuracy_mtl_test':accuracy_mtl_test_di_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ml,'f1-score_mtl_test':f1_mtl_test_di_ml,
            'precision_mtl_val':precision_mtl_val_di_ml, 'precision_mtl_test':precision_mtl_test_di_ml,
            'recall_mtl_val':recall_mtl_val_di_ml, 'recall_mtl_test':recall_mtl_test_di_ml})

# %%
models_results_df
# Out:
#    accuracy_mtl_test  accuracy_mtl_val  epochs  f1-score_mtl_test  \
# 0           0.752036          0.752179       1           0.586773
# 1           0.781565          0.786946       2           0.607320
# 2           0.805091          0.809277       3           0.613251
# 3           0.816975          0.817447       4           0.634294
# 4           0.813175          0.816267       5           0.631093
# 5           0.816553          0.821169       6           0.606569
# 6           0.820354          0.819535       7           0.627131
# 7           0.819720          0.829158       8           0.631093
# 8           0.828829          0.824891       9           0.637457
# 9           0.803825          0.802197      10           0.634113
#
#    f1-score_mtl_val  precision_mtl_test  precision_mtl_val  recall_mtl_test  \
# 0          0.591969            0.636222           0.638077         0.544457
# 1          0.611405            0.699301           0.703027         0.536723
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    accuracy_mtl_test  accuracy_mtl_val  epochs  f1-score_mtl_test  \
# 8           0.828829          0.824891       9           0.637457
#
#    f1-score_mtl_val  precision_mtl_test  precision_mtl_val  recall_mtl_test  \
# 8          0.638636             0.73568             0.7403         0.562372
#
#    recall_mtl_val
# 8        0.561524

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, loss_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, loss_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_di_mc)+np.array(loss_val_di_ml)
loss_test = np.array(loss_test_di_mc)+np.array(loss_test_di_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# ### Two Ontologies probabilities negative (fine-tunning)

# %%
ont_dir = results_dir + 'Two_Ontology_prob_neg_v2/'

# %% [markdown]
# #### Dish-Ingredient (the ontology contains the top-down relation between dishes and ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, balanced_accuracy_mtl_val_di_mc, loss_val_di_mc, f1_mtl_val_di_mc, precision_mtl_val_di_mc, recall_mtl_val_di_mc, \
epoch_mtl_val_di_ml, average_precision_mtl_val_di_ml, loss_val_di_ml, coverage_error_mtl_val_di_ml, f1_mtl_val_di_ml, precision_mtl_val_di_ml, \
ranking_loss_mtl_val_di_ml, recall_mtl_val_di_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_mc, accuracy_mtl_test_di_mc, balanced_accuracy_mtl_test_di_mc, loss_test_di_mc, f1_mtl_test_di_mc, precision_mtl_test_di_mc, recall_mtl_test_di_mc, \
epoch_mtl_test_di_ml, average_precision_mtl_test_di_ml, loss_test_di_ml, coverage_error_mtl_test_di_ml, f1_mtl_test_di_ml, precision_mtl_test_di_ml, \
ranking_loss_mtl_test_di_ml, recall_mtl_test_di_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_mc, accuracy_mtl_val_di_mc, accuracy_mtl_test_di_mc, epoch_mtl_val_di_ml,
                f1_mtl_val_di_ml, f1_mtl_test_di_ml, precision_mtl_val_di_ml, precision_mtl_test_di_ml, recall_mtl_val_di_ml, recall_mtl_test_di_ml, 'Dish-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_mc,'accuracy_mtl_test':accuracy_mtl_test_di_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ml,'f1-score_mtl_test':f1_mtl_test_di_ml,
            'precision_mtl_val':precision_mtl_val_di_ml, 'precision_mtl_test':precision_mtl_test_di_ml,
            'recall_mtl_val':recall_mtl_val_di_ml, 'recall_mtl_test':recall_mtl_test_di_ml})

# %%
models_results_df
# Out:
#    accuracy_mtl_test  accuracy_mtl_val  epochs  f1-score_mtl_test  \
# 0           0.765760          0.761619       1           0.583672
# 1           0.798667          0.800200       2           0.621158
# 2           0.791518          0.793573       3           0.611866
# 3           0.819750          0.821623       4           0.640227
# 4           0.822706          0.822440       5           0.643575
# 5           0.822887          0.825617       6           0.641177
# 6           0.830096          0.833061       7           0.651191
# 7           0.825059          0.831155       8           0.644706
# 8           0.832388          0.829611       9           0.633359
# 9           0.830609          0.835421      10           0.654325
#
#    f1-score_mtl_val  precision_mtl_test  precision_mtl_val  recall_mtl_test  \
# 0          0.588080            0.628534           0.633142         0.544788
# 1          0.622015            0.676261           0.677396         0.574359
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    accuracy_mtl_test  accuracy_mtl_val  epochs  f1-score_mtl_test  \
# 9           0.830609          0.835421      10           0.654325
#
#    f1-score_mtl_val  precision_mtl_test  precision_mtl_val  recall_mtl_test  \
# 9          0.658213            0.714851           0.717948         0.603248
#
#    recall_mtl_val
# 9        0.607656

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, loss_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, loss_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_di_mc)+np.array(loss_val_di_ml)
loss_test = np.array(loss_test_di_mc)+np.array(loss_test_di_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Ingredient-Ingredient (the ontology contains the coexistence relation between ingredients)

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, balanced_accuracy_mtl_val_ii_mc, loss_val_ii_mc, f1_mtl_val_ii_mc, precision_mtl_val_ii_mc, recall_mtl_val_ii_mc, \
epoch_mtl_val_ii_ml, average_precision_mtl_val_ii_ml, loss_val_ii_ml, coverage_error_mtl_val_ii_ml, f1_mtl_val_ii_ml, precision_mtl_val_ii_ml, \
ranking_loss_mtl_val_ii_ml, recall_mtl_val_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_ii_mc, accuracy_mtl_test_ii_mc, balanced_accuracy_mtl_test_ii_mc, loss_test_ii_mc, f1_mtl_test_ii_mc, precision_mtl_test_ii_mc, recall_mtl_test_ii_mc, \
epoch_mtl_test_ii_ml, average_precision_mtl_test_ii_ml, loss_test_ii_ml, coverage_error_mtl_test_ii_ml, f1_mtl_test_ii_ml, precision_mtl_test_ii_ml, \
ranking_loss_mtl_test_ii_ml, recall_mtl_test_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_ii_mc, accuracy_mtl_val_ii_mc, accuracy_mtl_test_ii_mc, epoch_mtl_val_ii_ml,
                f1_mtl_val_ii_ml, f1_mtl_test_ii_ml, precision_mtl_val_ii_ml, precision_mtl_test_ii_ml, recall_mtl_val_ii_ml, recall_mtl_test_ii_ml, 'Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_ii_ml,'f1-score_mtl_test':f1_mtl_test_ii_ml,
            'precision_mtl_val':precision_mtl_val_ii_ml, 'precision_mtl_test':precision_mtl_test_ii_ml,
            'recall_mtl_val':recall_mtl_val_ii_ml, 'recall_mtl_test':recall_mtl_test_ii_ml})

# %%
models_results_df
# Out:
#    accuracy_mtl_test  accuracy_mtl_val  epochs  f1-score_mtl_test  \
# 0           0.775683          0.774056       1           0.559365
# 1           0.780509          0.769063       2           0.555279
# 2           0.826838          0.829430       3           0.593338
# 3           0.801864          0.796387       4           0.606752
# 4           0.813718          0.813635       5           0.600560
# 5           0.832660          0.836783       6           0.630066
# 6           0.801170          0.802651       7           0.606628
# 7           0.838933          0.842411       8           0.641352
# 8           0.810490          0.813725       9           0.622140
# 9           0.829342          0.831699      10           0.642553
#
#    f1-score_mtl_val  precision_mtl_test  precision_mtl_val  recall_mtl_test  \
# 0          0.560479            0.579877           0.578521         0.540254
# 1          0.556407            0.674520           0.673711         0.471863
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    accuracy_mtl_test  accuracy_mtl_val  epochs  f1-score_mtl_test  \
# 9           0.829342          0.831699      10           0.642553
#
#    f1-score_mtl_val  precision_mtl_test  precision_mtl_val  recall_mtl_test  \
# 9          0.642986            0.721865           0.723235         0.578943
#
#    recall_mtl_val
# 9        0.578767

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_ingr_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_ingr_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, loss_di_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, loss_di_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_mc)+np.array(loss_di_ml)
loss_val = np.array(loss_val_ii_mc)+np.array(loss_val_ii_ml)
loss_test = np.array(loss_test_ii_mc)+np.array(loss_test_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_ii_mc, loss_val, label='val_loss')
ax.legend()

# %% [markdown]
# #### Dish-Ingredient Ingredient-Ingredient

# %%
mtl_val_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/val.multiclass_metrics'
mtl_val_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/val.multilabel_metrics'

# %%
epoch_mtl_val_di_ii_mc, accuracy_mtl_val_di_ii_mc, balanced_accuracy_mtl_val_di_ii_mc, loss_val_di_ii_mc, f1_mtl_val_di_ii_mc, precision_mtl_val_di_ii_mc, recall_mtl_val_di_ii_mc, \
epoch_mtl_val_di_ii_ml, average_precision_mtl_val_di_ii_ml, loss_val_di_ii_ml, coverage_error_mtl_val_di_ii_ml, f1_mtl_val_di_ii_ml, precision_mtl_val_di_ii_ml, \
ranking_loss_mtl_val_di_ii_ml, recall_mtl_val_di_ii_ml = dr.read_results(mtl_val_results_multiclass, mtl_val_results_multilabel, False)

# %%
mtl_test_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/test.multiclass_metrics'
mtl_test_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_test_di_ii_mc, accuracy_mtl_test_di_ii_mc, balanced_accuracy_mtl_test_di_ii_mc, loss_test_di_ii_mc, f1_mtl_test_di_ii_mc, precision_mtl_test_di_ii_mc, recall_mtl_test_di_ii_mc, \
epoch_mtl_test_di_ii_ml, average_precision_mtl_test_di_ii_ml, loss_test_di_ii_ml, coverage_error_mtl_test_di_ii_ml, f1_mtl_test_di_ii_ml, precision_mtl_test_di_ii_ml, \
ranking_loss_mtl_test_di_ii_ml, recall_mtl_test_di_ii_ml = dr.read_results(mtl_test_results_multiclass, mtl_test_results_multilabel, False)

# %%
dr.plot_metrics(epoch_mtl_val_di_ii_mc, accuracy_mtl_val_di_ii_mc, accuracy_mtl_test_di_ii_mc, epoch_mtl_val_di_ii_ml,
                f1_mtl_val_di_ii_ml, f1_mtl_test_di_ii_ml, precision_mtl_val_di_ii_ml, precision_mtl_test_di_ii_ml, recall_mtl_val_di_ii_ml, recall_mtl_test_di_ii_ml, 'Dish-Ingredient Ingredient-Ingredient')

# %% [markdown]
# #### Evaluation over test set

# %%
models_results_df = pd.DataFrame({'epochs':epoch_mtl_val_di_ii_mc,
            'accuracy_mtl_val':accuracy_mtl_val_di_ii_mc,'accuracy_mtl_test':accuracy_mtl_test_di_ii_mc,
            'f1-score_mtl_val':f1_mtl_val_di_ii_ml,'f1-score_mtl_test':f1_mtl_test_di_ii_ml,
            'precision_mtl_val':precision_mtl_val_di_ii_ml, 'precision_mtl_test':precision_mtl_test_di_ii_ml,
            'recall_mtl_val':recall_mtl_val_di_ii_ml, 'recall_mtl_test':recall_mtl_test_di_ii_ml})

# %%
models_results_df
# Out:
#    accuracy_mtl_test  accuracy_mtl_val  epochs  f1-score_mtl_test  \
# 0           0.729837          0.733115       1           0.558227
# 1           0.768595          0.770153       2           0.583164
# 2           0.797521          0.793936       3           0.611951
# 3           0.803251          0.802469       4           0.597827
# 4           0.817941          0.815178       5           0.625837
# 5           0.802045          0.802832       6           0.609080
# 6           0.802950          0.803377       7           0.628532
# 7           0.825602          0.826162       8           0.650195
# 8           0.833082          0.835058       9           0.657618
# 9           0.831152          0.829611      10           0.645268
#
#    f1-score_mtl_val  precision_mtl_test  precision_mtl_val  recall_mtl_test  \
# 0          0.561085            0.597442           0.600460         0.523843
# 1          0.582667            0.600551           0.599459         0.566756
# ...

# %%
models_results_df[models_results_df['f1-score_mtl_val'] == max(models_results_df['f1-score_mtl_val'])]
# Out:
#    accuracy_mtl_test  accuracy_mtl_val  epochs  f1-score_mtl_test  \
# 8           0.833082          0.835058       9           0.657618
#
#    f1-score_mtl_val  precision_mtl_test  precision_mtl_val  recall_mtl_test  \
# 8          0.660714            0.734824           0.740063         0.595093
#
#    recall_mtl_val
# 8        0.596732

# %%
mtl_results_multiclass = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/train.multiclass_metrics'
mtl_results_multilabel = ont_dir + 'food_multitask_dish_ingr_ingr_ingr_ont/train.multilabel_metrics'

# %%
epoch_mtl_di_ii_mc, accuracy_mtl_di_ii_mc, balanced_accuracy_mtl_di_ii_mc, loss_di_ii_mc, f1_mtl_di_ii_mc, precision_mtl_di_ii_mc, recall_mtl_di_ii_mc, \
epoch_mtl_di_ii_ml, average_precision_mtl_di_ii_ml, loss_di_ii_ml, coverage_error_mtl_di_ii_ml, f1_mtl_di_ii_ml, precision_mtl_di_ii_ml, \
ranking_loss_mtl_di_ii_ml, recall_mtl_di_ii_ml = dr.read_results(mtl_results_multiclass, mtl_results_multilabel, True)

# %%
loss = np.array(loss_di_ii_mc)+np.array(loss_di_ii_ml)
loss_val = np.array(loss_val_di_ii_mc)+np.array(loss_val_di_ii_ml)
loss_test = np.array(loss_test_di_ii_mc)+np.array(loss_test_di_ii_ml)
ax = plt.subplot(111)
ax.plot(epoch_mtl_di_ii_mc, loss, label='train_loss')
ax.plot(epoch_mtl_di_ii_mc, loss_val, label='val_loss')
ax.legend()
