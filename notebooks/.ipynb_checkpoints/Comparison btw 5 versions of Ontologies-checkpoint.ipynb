# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def read_results(mtl_results_multiclass, mtl_results_multilabel, validation):
#read results files and return metrics results as lists ready to be printed

    multiclass_file = open(mtl_results_multiclass)
    multiclass_results = multiclass_file.readlines()

    multilabel_file = open(mtl_results_multilabel)
    multilabel_results = multilabel_file.readlines()

    epoch_mc = []
    accuracy_mc = []
    balanced_accuracy_mc = []
    f1_mc = []
    precision_mc = []
    recall_mc = []

    if validation:
        for row in multiclass_results[1:]:
            #print(row.split(','))
            epoch_mc.append(int(row.split(',')[0]))
            accuracy_mc.append(float(row.split(',')[1]))
            balanced_accuracy_mc.append(float(row.split(',')[2]))
            f1_mc.append(float(row.split(',')[3]))
            precision_mc.append(float(row.split(',')[4]))
            recall_mc.append(float(row.split(',')[5]))
    else:
        for row in multiclass_results:
            #print(row.split(','))
            epoch_mc.append(int(row.split(',')[0]))
            accuracy_mc.append(float(row.split(',')[1]))
            balanced_accuracy_mc.append(float(row.split(',')[2]))
            f1_mc.append(float(row.split(',')[3]))
            precision_mc.append(float(row.split(',')[4]))
            recall_mc.append(float(row.split(',')[5]))

    epoch_ml = []
    average_precision_ml = []
    coverage_error_ml = []
    f1_ml = []
    precision_ml = []
    ranking_loss_ml = []
    recall_ml = []

    for row in multilabel_results:
        #print(row.split(','))
        epoch_ml.append(int(row.split(',')[0]))
        average_precision_ml.append(float(row.split(',')[1]))
        coverage_error_ml.append(float(row.split(',')[2]))
        f1_ml.append(float(row.split(',')[3]))
        precision_ml.append(float(row.split(',')[4]))
        ranking_loss_ml.append(float(row.split(',')[5]))
        recall_ml.append(float(row.split(',')[6]))
    
    return epoch_mc, accuracy_mc, balanced_accuracy_mc, f1_mc, precision_mc, recall_mc,\
    epoch_ml, average_precision_ml, coverage_error_ml, f1_ml, precision_ml, ranking_loss_ml, recall_ml
    
def plot_metrics(epoch_mc, accuracy_mc, epoch_ml, f1_ml):
    
    fig = plt.figure(figsize=(15,5))

    fig.add_subplot(1,2,1)
    plt.plot(epoch_mc,accuracy_mc)
    plt.xlabel('epochs')
    plt.ylabel('accuracy')
    plt.title('MultiClass Accuracy')
    plt.grid(True)

    fig.add_subplot(1,2,2)
    plt.plot(epoch_ml,f1_ml)
    plt.xlabel('epochs')
    plt.ylabel('f1-score')
    plt.title('MultiLabel F1-score')

    fig.suptitle('Multiple Task Learning', fontsize=18)
    fig.tight_layout()
    plt.grid(True)

# %% [markdown]
# # MTL

# %%
results_dir = '../models/'

mtl_dir = results_dir + 'food_multitask/'

# %%
mtl_results_multiclass = mtl_dir + 'test.multiclass_metrics'
mtl_results_multilabel = mtl_dir + 'test.multilabel_metrics'

epoch_mtl_mc, accuracy_mtl_mc, balanced_accuracy_mtl_mc, f1_mtl_mc, precision_mtl_mc, recall_mtl_mc, \
epoch_mtl_ml, average_precision_mtl_ml, coverage_error_mtl_ml, f1_mtl_ml, precision_mtl_ml, \
ranking_loss_mtl_ml, recall_mtl_ml = read_results(mtl_results_multiclass, mtl_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_mc, accuracy_mtl_mc, epoch_mtl_ml, f1_mtl_ml)

# %% [markdown]
# # Ontology (1,0)

# %%
results_dir = '../models/Ontologies_Recipes5K/'

ont_1_0 = results_dir + 'Ontology_1_0/'

# %% [markdown]
# ### Dish-Ingredient

# %%
mtl_di_results_multiclass = ont_1_0 + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_di_results_multilabel = ont_1_0 + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = read_results(mtl_di_results_multiclass, mtl_di_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_di_mc, accuracy_mtl_di_mc, epoch_mtl_di_ml, f1_mtl_di_ml)

# %% [markdown]
# ### Ingredient-Dish

# %%
mtl_id_results_multiclass = ont_1_0 + 'food_multitask_ingr_dish_ont/test.multiclass_metrics'
mtl_id_results_multilabel = ont_1_0 + 'food_multitask_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_id_mc, accuracy_mtl_id_mc, balanced_accuracy_mtl_id_mc, f1_mtl_id_mc, precision_mtl_id_mc, recall_mtl_id_mc, \
epoch_mtl_id_ml, average_precision_mtl_id_ml, coverage_error_mtl_id_ml, f1_mtl_id_ml, precision_mtl_id_ml, \
ranking_loss_mtl_id_ml, recall_mtl_id_ml = read_results(mtl_id_results_multiclass, mtl_id_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_id_mc, accuracy_mtl_id_mc, epoch_mtl_id_ml, f1_mtl_id_ml)

# %% [markdown]
# ### Dish-Ingredient Ingredient-Dish

# %%
mtl_di_id_results_multiclass = ont_1_0 + 'food_multitask_dish_ingr_ingr_dish_ont/test.multiclass_metrics'
mtl_di_id_results_multilabel = ont_1_0 + 'food_multitask_dish_ingr_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, balanced_accuracy_mtl_di_id_mc, f1_mtl_di_id_mc, precision_mtl_di_id_mc, recall_mtl_di_id_mc, \
epoch_mtl_di_id_ml, average_precision_mtl_di_id_ml, coverage_error_mtl_di_id_ml, f1_mtl_di_id_ml, precision_mtl_di_id_ml, \
ranking_loss_mtl_di_id_ml, recall_mtl_di_id_ml = read_results(mtl_di_id_results_multiclass, mtl_di_id_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, epoch_mtl_di_id_ml, f1_mtl_di_id_ml)

# %% [markdown]
# ### Ingredient-Ingredient

# %%
mtl_ii_results_multiclass = ont_1_0 + 'food_multitask_ingr_ingr_ont/test.multiclass_metrics'
mtl_ii_results_multilabel = ont_1_0 + 'food_multitask_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = read_results(mtl_ii_results_multiclass, mtl_ii_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_ii_mc, accuracy_mtl_ii_mc, epoch_mtl_ii_ml, f1_mtl_ii_ml)

# %% [markdown]
# ### Full

# %%
mtl_full_results_multiclass = ont_1_0 + 'food_multitask_full_ont/test.multiclass_metrics'
mtl_full_results_multilabel = ont_1_0 + 'food_multitask_full_ont/test.multilabel_metrics'

# %%
epoch_mtl_full_mc, accuracy_mtl_full_mc, balanced_accuracy_mtl_full_mc, f1_mtl_full_mc, precision_mtl_full_mc, recall_mtl_full_mc, \
epoch_mtl_full_ml, average_precision_mtl_full_ml, coverage_error_mtl_full_ml, f1_mtl_full_ml, precision_mtl_full_ml, \
ranking_loss_mtl_full_ml, recall_mtl_full_ml = read_results(mtl_full_results_multiclass, mtl_full_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_full_mc, accuracy_mtl_full_mc, epoch_mtl_full_ml, f1_mtl_full_ml)

# %% [markdown]
# ### Compact information of interest

# %%
models_results_ont1_df = pd.DataFrame({'epochs':epoch_mtl_di_mc,
            'accuracy_mtl':accuracy_mtl_mc,'f1-score_mtl':f1_mtl_ml,
            'accuracy_mtl_di':accuracy_mtl_di_mc,'f1-score_mtl_di':f1_mtl_di_ml,
             'accuracy_mtl_id':accuracy_mtl_id_mc,'f1-score_mtl_id':f1_mtl_id_ml,
            'accuracy_mtl_di_id':accuracy_mtl_di_id_mc,'f1-score_mtl_di_id':f1_mtl_di_id_ml,
             'accuracy_mtl_ii':accuracy_mtl_ii_mc,'f1-score_mtl_ii':f1_mtl_ii_ml,
              'accuracy_mtl_full':accuracy_mtl_full_mc,'f1-score_mtl_full':f1_mtl_full_ml})

# %% [markdown]
# ### Accuracy

# %%
plt.plot('epochs','accuracy_mtl',data=models_results_ont1_df)
plt.plot('epochs','accuracy_mtl_di',data=models_results_ont1_df)
plt.plot('epochs','accuracy_mtl_id',data=models_results_ont1_df)
plt.plot('epochs','accuracy_mtl_di_id',data=models_results_ont1_df)
plt.plot('epochs','accuracy_mtl_ii',data=models_results_ont1_df)
plt.plot('epochs','accuracy_mtl_full',data=models_results_ont1_df)
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Dish Results')
# Out:
# Text(0.5,1,'Dish Results')

# %% [markdown]
# ### F1-score

# %%
plt.plot('epochs','f1-score_mtl',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_di',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_id',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_di_id',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_ii',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_full',data=models_results_ont1_df)
plt.ylabel('F1-score')
plt.xlabel('epoch')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Ingredients Results')
# Out:
# Text(0.5,1,'Ingredients Results')

# %% [markdown]
# # Ontology (1,-1)

# %%
results_dir = '../models/Ontologies_Recipes5K/'

ont_1_neg = results_dir + 'Ontology_1_-1/'

# %% [markdown]
# ### Dish-Ingredient

# %%
mtl_di_results_multiclass = ont_1_neg + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_di_results_multilabel = ont_1_neg + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = read_results(mtl_di_results_multiclass, mtl_di_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_di_mc, accuracy_mtl_di_mc, epoch_mtl_di_ml, f1_mtl_di_ml)

# %% [markdown]
# ### Ingredient-Dish

# %%
mtl_id_results_multiclass = ont_1_neg + 'food_multitask_ingr_dish_ont/test.multiclass_metrics'
mtl_id_results_multilabel = ont_1_neg + 'food_multitask_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_id_mc, accuracy_mtl_id_mc, balanced_accuracy_mtl_id_mc, f1_mtl_id_mc, precision_mtl_id_mc, recall_mtl_id_mc, \
epoch_mtl_id_ml, average_precision_mtl_id_ml, coverage_error_mtl_id_ml, f1_mtl_id_ml, precision_mtl_id_ml, \
ranking_loss_mtl_id_ml, recall_mtl_id_ml = read_results(mtl_id_results_multiclass, mtl_id_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_id_mc, accuracy_mtl_id_mc, epoch_mtl_id_ml, f1_mtl_id_ml)

# %% [markdown]
# ### Dish-Ingredient Ingredient-Dish

# %%
mtl_di_id_results_multiclass = ont_1_neg + 'food_multitask_dish_ingr_ingr_dish_ont/test.multiclass_metrics'
mtl_di_id_results_multilabel = ont_1_neg + 'food_multitask_dish_ingr_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, balanced_accuracy_mtl_di_id_mc, f1_mtl_di_id_mc, precision_mtl_di_id_mc, recall_mtl_di_id_mc, \
epoch_mtl_di_id_ml, average_precision_mtl_di_id_ml, coverage_error_mtl_di_id_ml, f1_mtl_di_id_ml, precision_mtl_di_id_ml, \
ranking_loss_mtl_di_id_ml, recall_mtl_di_id_ml = read_results(mtl_di_id_results_multiclass, mtl_di_id_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, epoch_mtl_di_id_ml, f1_mtl_di_id_ml)

# %% [markdown]
# ### Ingredient-Ingredient

# %%
mtl_ii_results_multiclass = ont_1_neg + 'food_multitask_ingr_ingr_ont/test.multiclass_metrics'
mtl_ii_results_multilabel = ont_1_neg + 'food_multitask_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = read_results(mtl_ii_results_multiclass, mtl_ii_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_ii_mc, accuracy_mtl_ii_mc, epoch_mtl_ii_ml, f1_mtl_ii_ml)

# %% [markdown]
# ### Full

# %%
mtl_full_results_multiclass = ont_1_neg + 'food_multitask_full_ont/test.multiclass_metrics'
mtl_full_results_multilabel = ont_1_neg + 'food_multitask_full_ont/test.multilabel_metrics'

# %%
epoch_mtl_full_mc, accuracy_mtl_full_mc, balanced_accuracy_mtl_full_mc, f1_mtl_full_mc, precision_mtl_full_mc, recall_mtl_full_mc, \
epoch_mtl_full_ml, average_precision_mtl_full_ml, coverage_error_mtl_full_ml, f1_mtl_full_ml, precision_mtl_full_ml, \
ranking_loss_mtl_full_ml, recall_mtl_full_ml = read_results(mtl_full_results_multiclass, mtl_full_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_full_mc, accuracy_mtl_full_mc, epoch_mtl_full_ml, f1_mtl_full_ml)

# %% [markdown]
# ### Compact information of interest

# %%
models_results_ont2_df = pd.DataFrame({'epochs':epoch_mtl_di_mc,
            'accuracy_mtl':accuracy_mtl_mc,'f1-score_mtl':f1_mtl_ml,
            'accuracy_mtl_di':accuracy_mtl_di_mc,'f1-score_mtl_di':f1_mtl_di_ml,
             'accuracy_mtl_id':accuracy_mtl_id_mc,'f1-score_mtl_id':f1_mtl_id_ml,
            'accuracy_mtl_di_id':accuracy_mtl_di_id_mc,'f1-score_mtl_di_id':f1_mtl_di_id_ml,
             'accuracy_mtl_ii':accuracy_mtl_ii_mc,'f1-score_mtl_ii':f1_mtl_ii_ml,
              'accuracy_mtl_full':accuracy_mtl_full_mc,'f1-score_mtl_full':f1_mtl_full_ml})

# %% [markdown]
# ### Accuracy

# %%
plt.plot('epochs','accuracy_mtl',data=models_results_ont2_df)
plt.plot('epochs','accuracy_mtl_di',data=models_results_ont2_df)
plt.plot('epochs','accuracy_mtl_id',data=models_results_ont2_df)
plt.plot('epochs','accuracy_mtl_di_id',data=models_results_ont2_df)
plt.plot('epochs','accuracy_mtl_ii',data=models_results_ont2_df)
plt.plot('epochs','accuracy_mtl_full',data=models_results_ont2_df)
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Dish Results')
# Out:
# Text(0.5,1,'Dish Results')

# %% [markdown]
# ### F1-score

# %%
plt.plot('epochs','f1-score_mtl',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_di',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_id',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_di_id',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_ii',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_full',data=models_results_ont2_df)
plt.ylabel('F1-score')
plt.xlabel('epoch')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Ingredients Results')
# Out:
# Text(0.5,1,'Ingredients Results')

# %% [markdown]
# # Ontology (probabilities)

# %%
results_dir = '../models/Ontologies_Recipes5K/'

ont_prob = results_dir + 'Ontology_probabilities/'

# %% [markdown]
# ### Dish-Ingredient

# %%
mtl_di_results_multiclass = ont_prob + 'food_multitask_dish_ingr_ont/test.multiclass_metrics'
mtl_di_results_multilabel = ont_prob + 'food_multitask_dish_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_di_mc, accuracy_mtl_di_mc, balanced_accuracy_mtl_di_mc, f1_mtl_di_mc, precision_mtl_di_mc, recall_mtl_di_mc, \
epoch_mtl_di_ml, average_precision_mtl_di_ml, coverage_error_mtl_di_ml, f1_mtl_di_ml, precision_mtl_di_ml, \
ranking_loss_mtl_di_ml, recall_mtl_di_ml = read_results(mtl_di_results_multiclass, mtl_di_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_di_mc, accuracy_mtl_di_mc, epoch_mtl_di_ml, f1_mtl_di_ml)

# %% [markdown]
# ### Ingredient-Dish

# %%
mtl_id_results_multiclass = ont_prob + 'food_multitask_ingr_dish_ont/test.multiclass_metrics'
mtl_id_results_multilabel = ont_prob + 'food_multitask_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_id_mc, accuracy_mtl_id_mc, balanced_accuracy_mtl_id_mc, f1_mtl_id_mc, precision_mtl_id_mc, recall_mtl_id_mc, \
epoch_mtl_id_ml, average_precision_mtl_id_ml, coverage_error_mtl_id_ml, f1_mtl_id_ml, precision_mtl_id_ml, \
ranking_loss_mtl_id_ml, recall_mtl_id_ml = read_results(mtl_id_results_multiclass, mtl_id_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_id_mc, accuracy_mtl_id_mc, epoch_mtl_id_ml, f1_mtl_id_ml)

# %% [markdown]
# ### Dish-Ingredient Ingredient-Dish

# %%
mtl_di_id_results_multiclass = ont_prob + 'food_multitask_dish_ingr_ingr_dish_ont/test.multiclass_metrics'
mtl_di_id_results_multilabel = ont_prob + 'food_multitask_dish_ingr_ingr_dish_ont/test.multilabel_metrics'

# %%
epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, balanced_accuracy_mtl_di_id_mc, f1_mtl_di_id_mc, precision_mtl_di_id_mc, recall_mtl_di_id_mc, \
epoch_mtl_di_id_ml, average_precision_mtl_di_id_ml, coverage_error_mtl_di_id_ml, f1_mtl_di_id_ml, precision_mtl_di_id_ml, \
ranking_loss_mtl_di_id_ml, recall_mtl_di_id_ml = read_results(mtl_di_id_results_multiclass, mtl_di_id_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_di_id_mc, accuracy_mtl_di_id_mc, epoch_mtl_di_id_ml, f1_mtl_di_id_ml)

# %% [markdown]
# ### Ingredient-Ingredient

# %%
mtl_ii_results_multiclass = ont_prob + 'food_multitask_ingr_ingr_ont/test.multiclass_metrics'
mtl_ii_results_multilabel = ont_prob + 'food_multitask_ingr_ingr_ont/test.multilabel_metrics'

# %%
epoch_mtl_ii_mc, accuracy_mtl_ii_mc, balanced_accuracy_mtl_ii_mc, f1_mtl_ii_mc, precision_mtl_ii_mc, recall_mtl_ii_mc, \
epoch_mtl_ii_ml, average_precision_mtl_ii_ml, coverage_error_mtl_ii_ml, f1_mtl_ii_ml, precision_mtl_ii_ml, \
ranking_loss_mtl_ii_ml, recall_mtl_ii_ml = read_results(mtl_ii_results_multiclass, mtl_ii_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_ii_mc, accuracy_mtl_ii_mc, epoch_mtl_ii_ml, f1_mtl_ii_ml)

# %% [markdown]
# ### Full

# %%
mtl_full_results_multiclass = ont_prob + 'food_multitask_full_ont/test.multiclass_metrics'
mtl_full_results_multilabel = ont_prob + 'food_multitask_full_ont/test.multilabel_metrics'

# %%
epoch_mtl_full_mc, accuracy_mtl_full_mc, balanced_accuracy_mtl_full_mc, f1_mtl_full_mc, precision_mtl_full_mc, recall_mtl_full_mc, \
epoch_mtl_full_ml, average_precision_mtl_full_ml, coverage_error_mtl_full_ml, f1_mtl_full_ml, precision_mtl_full_ml, \
ranking_loss_mtl_full_ml, recall_mtl_full_ml = read_results(mtl_full_results_multiclass, mtl_full_results_multilabel, False)

# %%
plot_metrics(epoch_mtl_full_mc, accuracy_mtl_full_mc, epoch_mtl_full_ml, f1_mtl_full_ml)

# %% [markdown]
# ### Compact information of interest

# %%
models_results_ont3_df = pd.DataFrame({'epochs':epoch_mtl_di_mc,
            'accuracy_mtl':accuracy_mtl_mc,'f1-score_mtl':f1_mtl_ml,
            'accuracy_mtl_di':accuracy_mtl_di_mc,'f1-score_mtl_di':f1_mtl_di_ml,
             'accuracy_mtl_id':accuracy_mtl_id_mc,'f1-score_mtl_id':f1_mtl_id_ml,
            'accuracy_mtl_di_id':accuracy_mtl_di_id_mc,'f1-score_mtl_di_id':f1_mtl_di_id_ml,
             'accuracy_mtl_ii':accuracy_mtl_ii_mc,'f1-score_mtl_ii':f1_mtl_ii_ml,
              'accuracy_mtl_full':accuracy_mtl_full_mc,'f1-score_mtl_full':f1_mtl_full_ml})

# %% [markdown]
# ### Accuracy

# %%
plt.plot('epochs','accuracy_mtl',data=models_results_ont3_df)
plt.plot('epochs','accuracy_mtl_di',data=models_results_ont3_df)
plt.plot('epochs','accuracy_mtl_id',data=models_results_ont3_df)
plt.plot('epochs','accuracy_mtl_di_id',data=models_results_ont3_df)
plt.plot('epochs','accuracy_mtl_ii',data=models_results_ont3_df)
plt.plot('epochs','accuracy_mtl_full',data=models_results_ont3_df)
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Dish Results')
# Out:
# Text(0.5,1,'Dish Results')

# %% [markdown]
# ### F1-score

# %%
plt.plot('epochs','f1-score_mtl',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_di',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_id',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_di_id',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_ii',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_full',data=models_results_ont3_df)
plt.ylabel('F1-score')
plt.xlabel('epoch')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Ingredients Results')
# Out:
# Text(0.5,1,'Ingredients Results')

# %% [markdown]
# Join 3 plots into one figure

# %%
fig = plt.figure(figsize=(20,5))

fig.add_subplot(1,3,1)
plt.plot('epochs','f1-score_mtl',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_di',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_id',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_di_id',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_ii',data=models_results_ont1_df)
plt.plot('epochs','f1-score_mtl_full',data=models_results_ont1_df)
plt.ylabel('F1-score')
plt.xlabel('epoch')
plt.title('1,0')

fig.add_subplot(1,3,2)
plt.plot('epochs','f1-score_mtl',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_di',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_id',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_di_id',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_ii',data=models_results_ont2_df)
plt.plot('epochs','f1-score_mtl_full',data=models_results_ont2_df)
plt.ylabel('F1-score')
plt.xlabel('epoch')
plt.title('1,-1')

fig.add_subplot(1,3,3)
plt.plot('epochs','f1-score_mtl',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_di',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_id',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_di_id',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_ii',data=models_results_ont3_df)
plt.plot('epochs','f1-score_mtl_full',data=models_results_ont3_df)
plt.ylabel('F1-score')
plt.xlabel('epoch')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('Probs')
# Out:
# Text(0.5,1,'Probs')

# %%
SMALL_SIZE = 10
MEDIUM_SIZE = 15
BIGGER_SIZE = 20

plt.rc('font', size=MEDIUM_SIZE)
plt.rc('axes',titlesize=BIGGER_SIZE, labelsize=MEDIUM_SIZE)
plt.rc('legend', fontsize=MEDIUM_SIZE)
plt.rcParams["legend.borderpad"] = 0.4
#plt.rcParams["legend.borderaxespad"] = 0.01

f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(10,20))

ax1.plot('epochs','f1-score_mtl',data=models_results_ont1_df)
ax1.plot('epochs','f1-score_mtl_di',data=models_results_ont1_df)
ax1.plot('epochs','f1-score_mtl_id',data=models_results_ont1_df)
ax1.plot('epochs','f1-score_mtl_di_id',data=models_results_ont1_df)
ax1.plot('epochs','f1-score_mtl_ii',data=models_results_ont1_df)
ax1.plot('epochs','f1-score_mtl_full',data=models_results_ont1_df)
ax1.tick_params(labelsize=MEDIUM_SIZE)
ax1.set_ylabel('F1-score')
ax1.set_xlabel('epoch')
ax1.set_title('1,0')

ax2.plot('epochs','f1-score_mtl',data=models_results_ont2_df)
ax2.plot('epochs','f1-score_mtl_di',data=models_results_ont2_df)
ax2.plot('epochs','f1-score_mtl_id',data=models_results_ont2_df)
ax2.plot('epochs','f1-score_mtl_di_id',data=models_results_ont2_df)
ax2.plot('epochs','f1-score_mtl_ii',data=models_results_ont2_df)
ax2.plot('epochs','f1-score_mtl_full',data=models_results_ont2_df)
ax2.tick_params(labelsize=MEDIUM_SIZE)
ax2.set_xlabel('epoch')
ax2.set_title('1,-1')

ax3.plot('epochs','f1-score_mtl',data=models_results_ont3_df)
ax3.plot('epochs','f1-score_mtl_di',data=models_results_ont3_df)
ax3.plot('epochs','f1-score_mtl_id',data=models_results_ont3_df)
ax3.plot('epochs','f1-score_mtl_di_id',data=models_results_ont3_df)
ax3.plot('epochs','f1-score_mtl_ii',data=models_results_ont3_df)
ax3.plot('epochs','f1-score_mtl_full',data=models_results_ont3_df)
ax3.tick_params(labelsize=MEDIUM_SIZE)
ax3.set_xlabel('epoch')
ax3.set_title('Probs')
f.subplots_adjust(hspace=0.3)
labels = ['f1-score_mtl','f1-score_mtl_di','f1-score_mtl_id','f1-score_mtl_di_id','f1-score_mtl_ii','f1-score_mtl_full']
f.legend(labels,loc='upper center',ncol=3)
f.savefig('recipes5k_ingredients_f1score_1.jpeg')

# %%
SMALL_SIZE = 10
MEDIUM_SIZE = 20
BIGGER_SIZE = 30

plt.rc('font', size=MEDIUM_SIZE)
plt.rc('axes',titlesize=BIGGER_SIZE, labelsize=MEDIUM_SIZE)
plt.rc('legend', fontsize=MEDIUM_SIZE)
plt.rcParams["legend.borderpad"] = 0.1
#plt.rcParams["legend.borderaxespad"] = 0.01

f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True,figsize=(25,5))

ax1.plot('epochs','f1-score_mtl',data=models_results_ont1_df, linewidth=3)
ax1.plot('epochs','f1-score_mtl_di',data=models_results_ont1_df, linewidth=3)
ax1.plot('epochs','f1-score_mtl_id',data=models_results_ont1_df, linewidth=3)
ax1.plot('epochs','f1-score_mtl_di_id',data=models_results_ont1_df, linewidth=3)
ax1.plot('epochs','f1-score_mtl_ii',data=models_results_ont1_df, linewidth=3)
ax1.plot('epochs','f1-score_mtl_full',data=models_results_ont1_df, linewidth=3)
ax1.tick_params(labelsize=MEDIUM_SIZE)
ax1.set_ylabel('F1-score')
ax1.set_xlabel('epoch')
ax1.set_title('1,0')

ax2.plot('epochs','f1-score_mtl',data=models_results_ont2_df, linewidth=3)
ax2.plot('epochs','f1-score_mtl_di',data=models_results_ont2_df, linewidth=3)
ax2.plot('epochs','f1-score_mtl_id',data=models_results_ont2_df, linewidth=3)
ax2.plot('epochs','f1-score_mtl_di_id',data=models_results_ont2_df, linewidth=3)
ax2.plot('epochs','f1-score_mtl_ii',data=models_results_ont2_df, linewidth=3)
ax2.plot('epochs','f1-score_mtl_full',data=models_results_ont2_df, linewidth=3)
ax2.tick_params(labelsize=MEDIUM_SIZE)
ax2.set_xlabel('epoch')
ax2.set_title('1,-1')

ax3.plot('epochs','f1-score_mtl',data=models_results_ont3_df, linewidth=3)
ax3.plot('epochs','f1-score_mtl_di',data=models_results_ont3_df, linewidth=3)
ax3.plot('epochs','f1-score_mtl_id',data=models_results_ont3_df, linewidth=3)
ax3.plot('epochs','f1-score_mtl_di_id',data=models_results_ont3_df, linewidth=3)
ax3.plot('epochs','f1-score_mtl_ii',data=models_results_ont3_df, linewidth=3)
ax3.plot('epochs','f1-score_mtl_full',data=models_results_ont3_df, linewidth=3)
ax3.tick_params(labelsize=MEDIUM_SIZE)
ax3.set_xlabel('epoch')
ax3.set_title('Probs')
f.subplots_adjust(wspace=0.05)
labels = ['f1-score_mtl','f1-score_mtl_di','f1-score_mtl_id','f1-score_mtl_di_id','f1-score_mtl_ii','f1-score_mtl_full']
legend = ax3.legend(labels,loc="upper center",ncol=3, bbox_to_anchor=(-0.5,1.4))
f.savefig('recipes5k_ingredients_f1score.jpeg',bbox_extra_artists=[legend], bbox_inches='tight')
